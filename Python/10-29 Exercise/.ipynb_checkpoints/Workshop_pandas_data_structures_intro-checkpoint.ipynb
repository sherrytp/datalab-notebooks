# %% [markdown]
# # Workshop - pandas Data Structures Intro
#
# Work from the pandas documentation:
# - [`https://pandas.pydata.org/pandas-docs/stable/getting_started/dsintro.html`](https://pandas.pydata.org/pandas-docs/stable/getting_started/dsintro.html)

# %% [markdown]
# You might enjoy modifying some of the examples to use the diamonds dataframe:

# %%
import numpy as np 
import pandas as pd
diamonds_pdf = pd.read_csv('https://raw.githubusercontent.com/datalab-datasets/file-samples/master/diamonds.csv').drop(columns='Unnamed: 0') 
diamonds_pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
# carat      53940 non-null float64
# cut        53940 non-null object
# color      53940 non-null object
# clarity    53940 non-null object
# depth      53940 non-null float64
# table      53940 non-null float64
# price      53940 non-null int64
# x          53940 non-null float64
# y          53940 non-null float64
# z          53940 non-null float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds_pdf.index
# Out:
# RangeIndex(start=0, stop=53940, step=1)

# %%
diamonds_pdf.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
del diamonds_pdf['x']

# %%
color = diamonds_pdf.pop("color")
color
# Out:
# 0        E
# 1        E
# 2        E
# 3        I
# 4        J
# 5        J
# 6        I
# 7        H
# 8        E
# 9        H
# 10       J
# 11       J
# 12       F
# 13       J
# 14       E
# 15       E
# 16       I
# 17       J
# 18       J
# 19       J
# 20       I
# 21       E
# 22       H
# 23       J
# 24       J
# 25       G
# 26       I
# 27       J
# 28       D
# 29       F
#         ..
# 53910    E
# 53911    E
# 53912    F
# 53913    G
# 53914    I
# 53915    E
# 53916    D
# 53917    J
# 53918    I
# 53919    I
# 53920    E
# 53921    E
# 53922    D
# 53923    I
# 53924    I
# 53925    I
# 53926    E
# 53927    F
# 53928    E
# 53929    G
# 53930    E
# 53931    F
# 53932    E
# 53933    E
# 53934    D
# 53935    D
# 53936    D
# 53937    D
# 53938    H
# 53939    D
# Name: color, Length: 53940, dtype: object

# %%
diamonds_pdf['y'] = 'bar'
diamonds_pdf
# Out:
#        carat        cut clarity  depth  table  price    y     z
# 0       0.23      Ideal     SI2   61.5   55.0    326  bar  2.43
# 1       0.21    Premium     SI1   59.8   61.0    326  bar  2.31
# 2       0.23       Good     VS1   56.9   65.0    327  bar  2.31
# 3       0.29    Premium     VS2   62.4   58.0    334  bar  2.63
# 4       0.31       Good     SI2   63.3   58.0    335  bar  2.75
# 5       0.24  Very Good    VVS2   62.8   57.0    336  bar  2.48
# 6       0.24  Very Good    VVS1   62.3   57.0    336  bar  2.47
# 7       0.26  Very Good     SI1   61.9   55.0    337  bar  2.53
# 8       0.22       Fair     VS2   65.1   61.0    337  bar  2.49
# 9       0.23  Very Good     VS1   59.4   61.0    338  bar  2.39
# 10      0.30       Good     SI1   64.0   55.0    339  bar  2.73
# 11      0.23      Ideal     VS1   62.8   56.0    340  bar  2.46
# 12      0.22    Premium     SI1   60.4   61.0    342  bar  2.33
# 13      0.31      Ideal     SI2   62.2   54.0    344  bar  2.71
# 14      0.20    Premium     SI2   60.2   62.0    345  bar  2.27
# 15      0.32    Premium      I1   60.9   58.0    345  bar  2.68
# 16      0.30      Ideal     SI2   62.0   54.0    348  bar  2.68
# 17      0.30       Good     SI1   63.4   54.0    351  bar  2.70
# 18      0.30       Good     SI1   63.8   56.0    351  bar  2.71
# 19      0.30  Very Good     SI1   62.7   59.0    351  bar  2.66
# 20      0.30       Good     SI2   63.3   56.0    351  bar  2.71
# 21      0.23  Very Good     VS2   63.8   55.0    352  bar  2.48
# 22      0.23  Very Good     VS1   61.0   57.0    353  bar  2.41
# 23      0.31  Very Good     SI1   59.4   62.0    353  bar  2.62
# 24      0.31  Very Good     SI1   58.1   62.0    353  bar  2.59
# 25      0.23  Very Good    VVS2   60.4   58.0    354  bar  2.41
# 26      0.24    Premium     VS1   62.5   57.0    355  bar  2.47
# 27      0.30  Very Good     VS2   62.2   57.0    357  bar  2.67
# 28      0.23  Very Good     VS2   60.5   61.0    357  bar  2.40
# 29      0.23  Very Good     VS1   60.9   57.0    357  bar  2.42
# ...      ...        ...     ...    ...    ...    ...  ...   ...
# 53910   0.70    Premium     SI1   60.5   58.0   2753  bar  3.48
# 53911   0.57    Premium      IF   59.8   60.0   2753  bar  3.23
# 53912   0.61    Premium    VVS1   61.8   59.0   2753  bar  3.36
# 53913   0.80       Good     VS2   64.2   58.0   2753  bar  3.74
# 53914   0.84       Good     VS1   63.7   59.0   2753  bar  3.77
# 53915   0.77      Ideal     SI2   62.1   56.0   2753  bar  3.63
# 53916   0.74       Good     SI1   63.1   59.0   2753  bar  3.61
# 53917   0.90  Very Good     SI1   63.2   60.0   2753  bar  3.86
# 53918   0.76    Premium     VS1   59.3   62.0   2753  bar  3.49
# 53919   0.76      Ideal    VVS1   62.2   55.0   2753  bar  3.66
# 53920   0.70  Very Good     VS2   62.4   60.0   2755  bar  3.49
# 53921   0.70  Very Good     VS2   62.8   60.0   2755  bar  3.53
# 53922   0.70  Very Good     VS1   63.1   59.0   2755  bar  3.55
# 53923   0.73      Ideal     VS2   61.3   56.0   2756  bar  3.57
# 53924   0.73      Ideal     VS2   61.6   55.0   2756  bar  3.59
# 53925   0.79      Ideal     SI1   61.6   56.0   2756  bar  3.67
# 53926   0.71      Ideal     SI1   61.9   56.0   2756  bar  3.54
# 53927   0.79       Good     SI1   58.1   59.0   2756  bar  3.54
# 53928   0.79    Premium     SI2   61.4   58.0   2756  bar  3.68
# 53929   0.71      Ideal     VS1   61.4   56.0   2756  bar  3.53
# 53930   0.71    Premium     SI1   60.5   55.0   2756  bar  3.49
# 53931   0.71    Premium     SI1   59.8   62.0   2756  bar  3.43
# 53932   0.70  Very Good     VS2   60.5   59.0   2757  bar  3.47
# 53933   0.70  Very Good     VS2   61.2   59.0   2757  bar  3.49
# 53934   0.72    Premium     SI1   62.7   59.0   2757  bar  3.58
# 53935   0.72      Ideal     SI1   60.8   57.0   2757  bar  3.50
# 53936   0.72       Good     SI1   63.1   55.0   2757  bar  3.61
# 53937   0.70  Very Good     SI1   62.8   60.0   2757  bar  3.56
# 53938   0.86    Premium     SI2   61.0   58.0   2757  bar  3.74
# 53939   0.75      Ideal     SI2   62.2   55.0   2757  bar  3.64
#
# [53940 rows x 8 columns]

# %%
diamonds_pdf['z'] = diamonds_pdf['y'][:3]
diamonds_pdf
# Out:
#        carat        cut clarity  depth  table  price    y    z
# 0       0.23      Ideal     SI2   61.5   55.0    326  bar  bar
# 1       0.21    Premium     SI1   59.8   61.0    326  bar  bar
# 2       0.23       Good     VS1   56.9   65.0    327  bar  bar
# 3       0.29    Premium     VS2   62.4   58.0    334  bar  NaN
# 4       0.31       Good     SI2   63.3   58.0    335  bar  NaN
# 5       0.24  Very Good    VVS2   62.8   57.0    336  bar  NaN
# 6       0.24  Very Good    VVS1   62.3   57.0    336  bar  NaN
# 7       0.26  Very Good     SI1   61.9   55.0    337  bar  NaN
# 8       0.22       Fair     VS2   65.1   61.0    337  bar  NaN
# 9       0.23  Very Good     VS1   59.4   61.0    338  bar  NaN
# 10      0.30       Good     SI1   64.0   55.0    339  bar  NaN
# 11      0.23      Ideal     VS1   62.8   56.0    340  bar  NaN
# 12      0.22    Premium     SI1   60.4   61.0    342  bar  NaN
# 13      0.31      Ideal     SI2   62.2   54.0    344  bar  NaN
# 14      0.20    Premium     SI2   60.2   62.0    345  bar  NaN
# 15      0.32    Premium      I1   60.9   58.0    345  bar  NaN
# 16      0.30      Ideal     SI2   62.0   54.0    348  bar  NaN
# 17      0.30       Good     SI1   63.4   54.0    351  bar  NaN
# 18      0.30       Good     SI1   63.8   56.0    351  bar  NaN
# 19      0.30  Very Good     SI1   62.7   59.0    351  bar  NaN
# 20      0.30       Good     SI2   63.3   56.0    351  bar  NaN
# 21      0.23  Very Good     VS2   63.8   55.0    352  bar  NaN
# 22      0.23  Very Good     VS1   61.0   57.0    353  bar  NaN
# 23      0.31  Very Good     SI1   59.4   62.0    353  bar  NaN
# 24      0.31  Very Good     SI1   58.1   62.0    353  bar  NaN
# 25      0.23  Very Good    VVS2   60.4   58.0    354  bar  NaN
# 26      0.24    Premium     VS1   62.5   57.0    355  bar  NaN
# 27      0.30  Very Good     VS2   62.2   57.0    357  bar  NaN
# 28      0.23  Very Good     VS2   60.5   61.0    357  bar  NaN
# 29      0.23  Very Good     VS1   60.9   57.0    357  bar  NaN
# ...      ...        ...     ...    ...    ...    ...  ...  ...
# 53910   0.70    Premium     SI1   60.5   58.0   2753  bar  NaN
# 53911   0.57    Premium      IF   59.8   60.0   2753  bar  NaN
# 53912   0.61    Premium    VVS1   61.8   59.0   2753  bar  NaN
# 53913   0.80       Good     VS2   64.2   58.0   2753  bar  NaN
# 53914   0.84       Good     VS1   63.7   59.0   2753  bar  NaN
# 53915   0.77      Ideal     SI2   62.1   56.0   2753  bar  NaN
# 53916   0.74       Good     SI1   63.1   59.0   2753  bar  NaN
# 53917   0.90  Very Good     SI1   63.2   60.0   2753  bar  NaN
# 53918   0.76    Premium     VS1   59.3   62.0   2753  bar  NaN
# 53919   0.76      Ideal    VVS1   62.2   55.0   2753  bar  NaN
# 53920   0.70  Very Good     VS2   62.4   60.0   2755  bar  NaN
# 53921   0.70  Very Good     VS2   62.8   60.0   2755  bar  NaN
# 53922   0.70  Very Good     VS1   63.1   59.0   2755  bar  NaN
# 53923   0.73      Ideal     VS2   61.3   56.0   2756  bar  NaN
# 53924   0.73      Ideal     VS2   61.6   55.0   2756  bar  NaN
# 53925   0.79      Ideal     SI1   61.6   56.0   2756  bar  NaN
# 53926   0.71      Ideal     SI1   61.9   56.0   2756  bar  NaN
# 53927   0.79       Good     SI1   58.1   59.0   2756  bar  NaN
# 53928   0.79    Premium     SI2   61.4   58.0   2756  bar  NaN
# 53929   0.71      Ideal     VS1   61.4   56.0   2756  bar  NaN
# 53930   0.71    Premium     SI1   60.5   55.0   2756  bar  NaN
# 53931   0.71    Premium     SI1   59.8   62.0   2756  bar  NaN
# 53932   0.70  Very Good     VS2   60.5   59.0   2757  bar  NaN
# 53933   0.70  Very Good     VS2   61.2   59.0   2757  bar  NaN
# 53934   0.72    Premium     SI1   62.7   59.0   2757  bar  NaN
# 53935   0.72      Ideal     SI1   60.8   57.0   2757  bar  NaN
# 53936   0.72       Good     SI1   63.1   55.0   2757  bar  NaN
# 53937   0.70  Very Good     SI1   62.8   60.0   2757  bar  NaN
# 53938   0.86    Premium     SI2   61.0   58.0   2757  bar  NaN
# 53939   0.75      Ideal     SI2   62.2   55.0   2757  bar  NaN
#
# [53940 rows x 8 columns]

# %%
diamonds_pdf.insert(1, "bar", diamonds_pdf['table'])
diamonds_pdf
# Out:
#        carat   bar        cut clarity  depth  table  price    y    z
# 0       0.23  55.0      Ideal     SI2   61.5   55.0    326  bar  bar
# 1       0.21  61.0    Premium     SI1   59.8   61.0    326  bar  bar
# 2       0.23  65.0       Good     VS1   56.9   65.0    327  bar  bar
# 3       0.29  58.0    Premium     VS2   62.4   58.0    334  bar  NaN
# 4       0.31  58.0       Good     SI2   63.3   58.0    335  bar  NaN
# 5       0.24  57.0  Very Good    VVS2   62.8   57.0    336  bar  NaN
# 6       0.24  57.0  Very Good    VVS1   62.3   57.0    336  bar  NaN
# 7       0.26  55.0  Very Good     SI1   61.9   55.0    337  bar  NaN
# 8       0.22  61.0       Fair     VS2   65.1   61.0    337  bar  NaN
# 9       0.23  61.0  Very Good     VS1   59.4   61.0    338  bar  NaN
# 10      0.30  55.0       Good     SI1   64.0   55.0    339  bar  NaN
# 11      0.23  56.0      Ideal     VS1   62.8   56.0    340  bar  NaN
# 12      0.22  61.0    Premium     SI1   60.4   61.0    342  bar  NaN
# 13      0.31  54.0      Ideal     SI2   62.2   54.0    344  bar  NaN
# 14      0.20  62.0    Premium     SI2   60.2   62.0    345  bar  NaN
# 15      0.32  58.0    Premium      I1   60.9   58.0    345  bar  NaN
# 16      0.30  54.0      Ideal     SI2   62.0   54.0    348  bar  NaN
# 17      0.30  54.0       Good     SI1   63.4   54.0    351  bar  NaN
# 18      0.30  56.0       Good     SI1   63.8   56.0    351  bar  NaN
# 19      0.30  59.0  Very Good     SI1   62.7   59.0    351  bar  NaN
# 20      0.30  56.0       Good     SI2   63.3   56.0    351  bar  NaN
# 21      0.23  55.0  Very Good     VS2   63.8   55.0    352  bar  NaN
# 22      0.23  57.0  Very Good     VS1   61.0   57.0    353  bar  NaN
# 23      0.31  62.0  Very Good     SI1   59.4   62.0    353  bar  NaN
# 24      0.31  62.0  Very Good     SI1   58.1   62.0    353  bar  NaN
# 25      0.23  58.0  Very Good    VVS2   60.4   58.0    354  bar  NaN
# 26      0.24  57.0    Premium     VS1   62.5   57.0    355  bar  NaN
# 27      0.30  57.0  Very Good     VS2   62.2   57.0    357  bar  NaN
# 28      0.23  61.0  Very Good     VS2   60.5   61.0    357  bar  NaN
# 29      0.23  57.0  Very Good     VS1   60.9   57.0    357  bar  NaN
# ...      ...   ...        ...     ...    ...    ...    ...  ...  ...
# 53910   0.70  58.0    Premium     SI1   60.5   58.0   2753  bar  NaN
# 53911   0.57  60.0    Premium      IF   59.8   60.0   2753  bar  NaN
# 53912   0.61  59.0    Premium    VVS1   61.8   59.0   2753  bar  NaN
# 53913   0.80  58.0       Good     VS2   64.2   58.0   2753  bar  NaN
# 53914   0.84  59.0       Good     VS1   63.7   59.0   2753  bar  NaN
# 53915   0.77  56.0      Ideal     SI2   62.1   56.0   2753  bar  NaN
# 53916   0.74  59.0       Good     SI1   63.1   59.0   2753  bar  NaN
# 53917   0.90  60.0  Very Good     SI1   63.2   60.0   2753  bar  NaN
# 53918   0.76  62.0    Premium     VS1   59.3   62.0   2753  bar  NaN
# 53919   0.76  55.0      Ideal    VVS1   62.2   55.0   2753  bar  NaN
# 53920   0.70  60.0  Very Good     VS2   62.4   60.0   2755  bar  NaN
# 53921   0.70  60.0  Very Good     VS2   62.8   60.0   2755  bar  NaN
# 53922   0.70  59.0  Very Good     VS1   63.1   59.0   2755  bar  NaN
# 53923   0.73  56.0      Ideal     VS2   61.3   56.0   2756  bar  NaN
# 53924   0.73  55.0      Ideal     VS2   61.6   55.0   2756  bar  NaN
# 53925   0.79  56.0      Ideal     SI1   61.6   56.0   2756  bar  NaN
# 53926   0.71  56.0      Ideal     SI1   61.9   56.0   2756  bar  NaN
# 53927   0.79  59.0       Good     SI1   58.1   59.0   2756  bar  NaN
# 53928   0.79  58.0    Premium     SI2   61.4   58.0   2756  bar  NaN
# 53929   0.71  56.0      Ideal     VS1   61.4   56.0   2756  bar  NaN
# 53930   0.71  55.0    Premium     SI1   60.5   55.0   2756  bar  NaN
# 53931   0.71  62.0    Premium     SI1   59.8   62.0   2756  bar  NaN
# 53932   0.70  59.0  Very Good     VS2   60.5   59.0   2757  bar  NaN
# 53933   0.70  59.0  Very Good     VS2   61.2   59.0   2757  bar  NaN
# 53934   0.72  59.0    Premium     SI1   62.7   59.0   2757  bar  NaN
# 53935   0.72  57.0      Ideal     SI1   60.8   57.0   2757  bar  NaN
# 53936   0.72  55.0       Good     SI1   63.1   55.0   2757  bar  NaN
# 53937   0.70  60.0  Very Good     SI1   62.8   60.0   2757  bar  NaN
# 53938   0.86  58.0    Premium     SI2   61.0   58.0   2757  bar  NaN
# 53939   0.75  55.0      Ideal     SI2   62.2   55.0   2757  bar  NaN
#
# [53940 rows x 9 columns]

# %%
diamonds_pdf.assign(price_fe = lambda x: (x['price'] - diamonds_pdf.price.mean()))
# Out:
#        carat   bar        cut clarity  depth  table  price    y    z  \
# 0       0.23  55.0      Ideal     SI2   61.5   55.0    326  bar  bar
# 1       0.21  61.0    Premium     SI1   59.8   61.0    326  bar  bar
# 2       0.23  65.0       Good     VS1   56.9   65.0    327  bar  bar
# 3       0.29  58.0    Premium     VS2   62.4   58.0    334  bar  NaN
# 4       0.31  58.0       Good     SI2   63.3   58.0    335  bar  NaN
# 5       0.24  57.0  Very Good    VVS2   62.8   57.0    336  bar  NaN
# 6       0.24  57.0  Very Good    VVS1   62.3   57.0    336  bar  NaN
# 7       0.26  55.0  Very Good     SI1   61.9   55.0    337  bar  NaN
# 8       0.22  61.0       Fair     VS2   65.1   61.0    337  bar  NaN
# 9       0.23  61.0  Very Good     VS1   59.4   61.0    338  bar  NaN
# 10      0.30  55.0       Good     SI1   64.0   55.0    339  bar  NaN
# 11      0.23  56.0      Ideal     VS1   62.8   56.0    340  bar  NaN
# 12      0.22  61.0    Premium     SI1   60.4   61.0    342  bar  NaN
# 13      0.31  54.0      Ideal     SI2   62.2   54.0    344  bar  NaN
# 14      0.20  62.0    Premium     SI2   60.2   62.0    345  bar  NaN
# 15      0.32  58.0    Premium      I1   60.9   58.0    345  bar  NaN
# 16      0.30  54.0      Ideal     SI2   62.0   54.0    348  bar  NaN
# 17      0.30  54.0       Good     SI1   63.4   54.0    351  bar  NaN
# 18      0.30  56.0       Good     SI1   63.8   56.0    351  bar  NaN
# 19      0.30  59.0  Very Good     SI1   62.7   59.0    351  bar  NaN
# 20      0.30  56.0       Good     SI2   63.3   56.0    351  bar  NaN
# 21      0.23  55.0  Very Good     VS2   63.8   55.0    352  bar  NaN
# 22      0.23  57.0  Very Good     VS1   61.0   57.0    353  bar  NaN
# 23      0.31  62.0  Very Good     SI1   59.4   62.0    353  bar  NaN
# 24      0.31  62.0  Very Good     SI1   58.1   62.0    353  bar  NaN
# 25      0.23  58.0  Very Good    VVS2   60.4   58.0    354  bar  NaN
# 26      0.24  57.0    Premium     VS1   62.5   57.0    355  bar  NaN
# 27      0.30  57.0  Very Good     VS2   62.2   57.0    357  bar  NaN
# 28      0.23  61.0  Very Good     VS2   60.5   61.0    357  bar  NaN
# 29      0.23  57.0  Very Good     VS1   60.9   57.0    357  bar  NaN
# ...      ...   ...        ...     ...    ...    ...    ...  ...  ...
# 53910   0.70  58.0    Premium     SI1   60.5   58.0   2753  bar  NaN
# 53911   0.57  60.0    Premium      IF   59.8   60.0   2753  bar  NaN
# 53912   0.61  59.0    Premium    VVS1   61.8   59.0   2753  bar  NaN
# 53913   0.80  58.0       Good     VS2   64.2   58.0   2753  bar  NaN
# 53914   0.84  59.0       Good     VS1   63.7   59.0   2753  bar  NaN
# 53915   0.77  56.0      Ideal     SI2   62.1   56.0   2753  bar  NaN
# 53916   0.74  59.0       Good     SI1   63.1   59.0   2753  bar  NaN
# 53917   0.90  60.0  Very Good     SI1   63.2   60.0   2753  bar  NaN
# 53918   0.76  62.0    Premium     VS1   59.3   62.0   2753  bar  NaN
# 53919   0.76  55.0      Ideal    VVS1   62.2   55.0   2753  bar  NaN
# 53920   0.70  60.0  Very Good     VS2   62.4   60.0   2755  bar  NaN
# 53921   0.70  60.0  Very Good     VS2   62.8   60.0   2755  bar  NaN
# 53922   0.70  59.0  Very Good     VS1   63.1   59.0   2755  bar  NaN
# 53923   0.73  56.0      Ideal     VS2   61.3   56.0   2756  bar  NaN
# 53924   0.73  55.0      Ideal     VS2   61.6   55.0   2756  bar  NaN
# 53925   0.79  56.0      Ideal     SI1   61.6   56.0   2756  bar  NaN
# 53926   0.71  56.0      Ideal     SI1   61.9   56.0   2756  bar  NaN
# 53927   0.79  59.0       Good     SI1   58.1   59.0   2756  bar  NaN
# 53928   0.79  58.0    Premium     SI2   61.4   58.0   2756  bar  NaN
# 53929   0.71  56.0      Ideal     VS1   61.4   56.0   2756  bar  NaN
# 53930   0.71  55.0    Premium     SI1   60.5   55.0   2756  bar  NaN
# 53931   0.71  62.0    Premium     SI1   59.8   62.0   2756  bar  NaN
# 53932   0.70  59.0  Very Good     VS2   60.5   59.0   2757  bar  NaN
# 53933   0.70  59.0  Very Good     VS2   61.2   59.0   2757  bar  NaN
# 53934   0.72  59.0    Premium     SI1   62.7   59.0   2757  bar  NaN
# 53935   0.72  57.0      Ideal     SI1   60.8   57.0   2757  bar  NaN
# 53936   0.72  55.0       Good     SI1   63.1   55.0   2757  bar  NaN
# 53937   0.70  60.0  Very Good     SI1   62.8   60.0   2757  bar  NaN
# 53938   0.86  58.0    Premium     SI2   61.0   58.0   2757  bar  NaN
# 53939   0.75  55.0      Ideal     SI2   62.2   55.0   2757  bar  NaN
#
#           price_fe
# 0     -3606.799722
# 1     -3606.799722
# 2     -3605.799722
# 3     -3598.799722
# 4     -3597.799722
# 5     -3596.799722
# 6     -3596.799722
# 7     -3595.799722
# 8     -3595.799722
# 9     -3594.799722
# 10    -3593.799722
# 11    -3592.799722
# 12    -3590.799722
# 13    -3588.799722
# 14    -3587.799722
# 15    -3587.799722
# 16    -3584.799722
# 17    -3581.799722
# 18    -3581.799722
# 19    -3581.799722
# 20    -3581.799722
# 21    -3580.799722
# 22    -3579.799722
# 23    -3579.799722
# 24    -3579.799722
# 25    -3578.799722
# 26    -3577.799722
# 27    -3575.799722
# 28    -3575.799722
# 29    -3575.799722
# ...            ...
# 53910 -1179.799722
# 53911 -1179.799722
# 53912 -1179.799722
# 53913 -1179.799722
# 53914 -1179.799722
# 53915 -1179.799722
# 53916 -1179.799722
# 53917 -1179.799722
# 53918 -1179.799722
# 53919 -1179.799722
# 53920 -1177.799722
# 53921 -1177.799722
# 53922 -1177.799722
# 53923 -1176.799722
# 53924 -1176.799722
# 53925 -1176.799722
# 53926 -1176.799722
# 53927 -1176.799722
# 53928 -1176.799722
# 53929 -1176.799722
# 53930 -1176.799722
# 53931 -1176.799722
# 53932 -1175.799722
# 53933 -1175.799722
# 53934 -1175.799722
# 53935 -1175.799722
# 53936 -1175.799722
# 53937 -1175.799722
# 53938 -1175.799722
# 53939 -1175.799722
#
# [53940 rows x 10 columns]

# %%
from sklearn import datasets 
iris = datasets.load_iris()
(iris.query('SepalLength > 5')
 .assign(SepalRatio=lambda x: x.SepalWidth / x.SepalLength, 
         PetalRatio=lambda x: x.PetalWidth / x.PetalLength)
 .plot(kind='scatter', x='SepalRatio', y='PetalRatio'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#     104         try:
# --> 105             return self[key]
#     106         except KeyError:
#
# KeyError: 'query'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-1e328adaa097> in <module>
#       1 from sklearn import datasets
#       2 iris = datasets.load_iris()
# ----> 3 (iris.query('SepalLength > 5')
#       4  .assign(SepalRatio=lambda x: x.SepalWidth / x.SepalLength,
#       5          PetalRatio=lambda x: x.PetalWidth / x.PetalLength)
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/__init__.py in __getattr__(self, key)
#     105             return self[key]
#     106         except KeyError:
# --> 107             raise AttributeError(key)
#     108
#     109     def __setstate__(self, state):
#
# AttributeError: query

# %%
print(diamonds_pdf.iloc[-20:, :12].to_string())
# Out:
#        carat   bar        cut clarity  depth  table  price    y    z
# 53920   0.70  60.0  Very Good     VS2   62.4   60.0   2755  bar  NaN
# 53921   0.70  60.0  Very Good     VS2   62.8   60.0   2755  bar  NaN
# 53922   0.70  59.0  Very Good     VS1   63.1   59.0   2755  bar  NaN
# 53923   0.73  56.0      Ideal     VS2   61.3   56.0   2756  bar  NaN
# 53924   0.73  55.0      Ideal     VS2   61.6   55.0   2756  bar  NaN
# 53925   0.79  56.0      Ideal     SI1   61.6   56.0   2756  bar  NaN
# 53926   0.71  56.0      Ideal     SI1   61.9   56.0   2756  bar  NaN
# 53927   0.79  59.0       Good     SI1   58.1   59.0   2756  bar  NaN
# 53928   0.79  58.0    Premium     SI2   61.4   58.0   2756  bar  NaN
# 53929   0.71  56.0      Ideal     VS1   61.4   56.0   2756  bar  NaN
# 53930   0.71  55.0    Premium     SI1   60.5   55.0   2756  bar  NaN
# 53931   0.71  62.0    Premium     SI1   59.8   62.0   2756  bar  NaN
# 53932   0.70  59.0  Very Good     VS2   60.5   59.0   2757  bar  NaN
# 53933   0.70  59.0  Very Good     VS2   61.2   59.0   2757  bar  NaN
# 53934   0.72  59.0    Premium     SI1   62.7   59.0   2757  bar  NaN
# 53935   0.72  57.0      Ideal     SI1   60.8   57.0   2757  bar  NaN
# 53936   0.72  55.0       Good     SI1   63.1   55.0   2757  bar  NaN
# 53937   0.70  60.0  Very Good     SI1   62.8   60.0   2757  bar  NaN
# 53938   0.86  58.0    Premium     SI2   61.0   58.0   2757  bar  NaN
# 53939   0.75  55.0      Ideal     SI2   62.2   55.0   2757  bar  NaN

# %%
pd.set_option("display.width", 40)
diamonds_pdf
# Out:
#        carat   bar        cut clarity  \
# 0       0.23  55.0      Ideal     SI2
# 1       0.21  61.0    Premium     SI1
# 2       0.23  65.0       Good     VS1
# 3       0.29  58.0    Premium     VS2
# 4       0.31  58.0       Good     SI2
# 5       0.24  57.0  Very Good    VVS2
# 6       0.24  57.0  Very Good    VVS1
# 7       0.26  55.0  Very Good     SI1
# 8       0.22  61.0       Fair     VS2
# 9       0.23  61.0  Very Good     VS1
# 10      0.30  55.0       Good     SI1
# 11      0.23  56.0      Ideal     VS1
# 12      0.22  61.0    Premium     SI1
# 13      0.31  54.0      Ideal     SI2
# 14      0.20  62.0    Premium     SI2
# 15      0.32  58.0    Premium      I1
# 16      0.30  54.0      Ideal     SI2
# 17      0.30  54.0       Good     SI1
# 18      0.30  56.0       Good     SI1
# 19      0.30  59.0  Very Good     SI1
# 20      0.30  56.0       Good     SI2
# 21      0.23  55.0  Very Good     VS2
# 22      0.23  57.0  Very Good     VS1
# 23      0.31  62.0  Very Good     SI1
# 24      0.31  62.0  Very Good     SI1
# 25      0.23  58.0  Very Good    VVS2
# 26      0.24  57.0    Premium     VS1
# 27      0.30  57.0  Very Good     VS2
# 28      0.23  61.0  Very Good     VS2
# 29      0.23  57.0  Very Good     VS1
# ...      ...   ...        ...     ...
# 53910   0.70  58.0    Premium     SI1
# 53911   0.57  60.0    Premium      IF
# 53912   0.61  59.0    Premium    VVS1
# 53913   0.80  58.0       Good     VS2
# 53914   0.84  59.0       Good     VS1
# 53915   0.77  56.0      Ideal     SI2
# 53916   0.74  59.0       Good     SI1
# 53917   0.90  60.0  Very Good     SI1
# 53918   0.76  62.0    Premium     VS1
# 53919   0.76  55.0      Ideal    VVS1
# 53920   0.70  60.0  Very Good     VS2
# 53921   0.70  60.0  Very Good     VS2
# 53922   0.70  59.0  Very Good     VS1
# 53923   0.73  56.0      Ideal     VS2
# 53924   0.73  55.0      Ideal     VS2
# 53925   0.79  56.0      Ideal     SI1
# 53926   0.71  56.0      Ideal     SI1
# 53927   0.79  59.0       Good     SI1
# 53928   0.79  58.0    Premium     SI2
# 53929   0.71  56.0      Ideal     VS1
# 53930   0.71  55.0    Premium     SI1
# 53931   0.71  62.0    Premium     SI1
# 53932   0.70  59.0  Very Good     VS2
# 53933   0.70  59.0  Very Good     VS2
# 53934   0.72  59.0    Premium     SI1
# 53935   0.72  57.0      Ideal     SI1
# 53936   0.72  55.0       Good     SI1
# 53937   0.70  60.0  Very Good     SI1
# 53938   0.86  58.0    Premium     SI2
# 53939   0.75  55.0      Ideal     SI2
#
#        depth  table  price    y    z
# 0       61.5   55.0    326  bar  bar
# 1       59.8   61.0    326  bar  bar
# 2       56.9   65.0    327  bar  bar
# 3       62.4   58.0    334  bar  NaN
# 4       63.3   58.0    335  bar  NaN
# 5       62.8   57.0    336  bar  NaN
# 6       62.3   57.0    336  bar  NaN
# 7       61.9   55.0    337  bar  NaN
# 8       65.1   61.0    337  bar  NaN
# 9       59.4   61.0    338  bar  NaN
# 10      64.0   55.0    339  bar  NaN
# 11      62.8   56.0    340  bar  NaN
# 12      60.4   61.0    342  bar  NaN
# 13      62.2   54.0    344  bar  NaN
# 14      60.2   62.0    345  bar  NaN
# 15      60.9   58.0    345  bar  NaN
# 16      62.0   54.0    348  bar  NaN
# 17      63.4   54.0    351  bar  NaN
# 18      63.8   56.0    351  bar  NaN
# 19      62.7   59.0    351  bar  NaN
# 20      63.3   56.0    351  bar  NaN
# 21      63.8   55.0    352  bar  NaN
# 22      61.0   57.0    353  bar  NaN
# 23      59.4   62.0    353  bar  NaN
# 24      58.1   62.0    353  bar  NaN
# 25      60.4   58.0    354  bar  NaN
# 26      62.5   57.0    355  bar  NaN
# 27      62.2   57.0    357  bar  NaN
# 28      60.5   61.0    357  bar  NaN
# 29      60.9   57.0    357  bar  NaN
# ...      ...    ...    ...  ...  ...
# 53910   60.5   58.0   2753  bar  NaN
# 53911   59.8   60.0   2753  bar  NaN
# 53912   61.8   59.0   2753  bar  NaN
# 53913   64.2   58.0   2753  bar  NaN
# 53914   63.7   59.0   2753  bar  NaN
# 53915   62.1   56.0   2753  bar  NaN
# 53916   63.1   59.0   2753  bar  NaN
# 53917   63.2   60.0   2753  bar  NaN
# 53918   59.3   62.0   2753  bar  NaN
# 53919   62.2   55.0   2753  bar  NaN
# 53920   62.4   60.0   2755  bar  NaN
# 53921   62.8   60.0   2755  bar  NaN
# 53922   63.1   59.0   2755  bar  NaN
# 53923   61.3   56.0   2756  bar  NaN
# 53924   61.6   55.0   2756  bar  NaN
# 53925   61.6   56.0   2756  bar  NaN
# 53926   61.9   56.0   2756  bar  NaN
# 53927   58.1   59.0   2756  bar  NaN
# 53928   61.4   58.0   2756  bar  NaN
# 53929   61.4   56.0   2756  bar  NaN
# 53930   60.5   55.0   2756  bar  NaN
# 53931   59.8   62.0   2756  bar  NaN
# 53932   60.5   59.0   2757  bar  NaN
# 53933   61.2   59.0   2757  bar  NaN
# 53934   62.7   59.0   2757  bar  NaN
# 53935   60.8   57.0   2757  bar  NaN
# 53936   63.1   55.0   2757  bar  NaN
# 53937   62.8   60.0   2757  bar  NaN
# 53938   61.0   58.0   2757  bar  NaN
# 53939   62.2   55.0   2757  bar  NaN
#
# [53940 rows x 9 columns]

# %% [markdown]
# # Time Series

# %%
rng = pd.date_range("1/1/2012", periods = 100, freq = "S")
ts = pd.Series(np.random.randint(0, 500, len(rng)), index = rng) 
ts.resample('5Min').sum()
# Out:
# 2012-01-01    24320
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2012 00:00", periods = 5, freq = "D")
ts = pd.Series(np.random.randn(len(rng)), rng)
ts
# Out:
# 2012-03-06    0.745063
# 2012-03-07   -1.487039
# 2012-03-08    0.416992
# 2012-03-09    0.668778
# 2012-03-10    0.520620
# Freq: D, dtype: float64

# %%
ts.tz_localize("UTC")
# Out:
# 2012-03-06 00:00:00+00:00    0.745063
# 2012-03-07 00:00:00+00:00   -1.487039
# 2012-03-08 00:00:00+00:00    0.416992
# 2012-03-09 00:00:00+00:00    0.668778
# 2012-03-10 00:00:00+00:00    0.520620
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2012-03-05 19:00:00-05:00    0.745063
# 2012-03-06 19:00:00-05:00   -1.487039
# 2012-03-07 19:00:00-05:00    0.416992
# 2012-03-08 19:00:00-05:00    0.668778
# 2012-03-09 19:00:00-05:00    0.520620
# Freq: D, dtype: float64

# %%
ps = ts.to_period()
ps
# Out:
# 2012-03-06    0.745063
# 2012-03-07   -1.487039
# 2012-03-08    0.416992
# 2012-03-09    0.668778
# 2012-03-10    0.520620
# Freq: D, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-03-06    0.745063
# 2012-03-07   -1.487039
# 2012-03-08    0.416992
# 2012-03-09    0.668778
# 2012-03-10    0.520620
# Freq: D, dtype: float64

# %% [markdown]
# The end.
