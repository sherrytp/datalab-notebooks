# %% [markdown]
# # Introduction to Tweepy

# %%
import sys
sys.version
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">35</span><span class="ansired">]: </span>&apos;3.5.2 (default, Sep 14 2017, 22:51:06) \n[GCC 5.4.0 20160609]&apos;
# </div>

# %% [markdown]
# ## 1. Twitter API and retrieving tokens

# %% [markdown]
# `Tweepy` is a library for accessing the Twitter API. This is how Twitter API works.

# %% [markdown]
# ![alt](https://cms-assets.tutsplus.com/uploads/users/317/posts/22192/image/streaming-intro-1_1.png)

# %% [markdown]
# In order to get data from Twitter, we need to have consumer and access tokens. The consumer key and consumer secret are values you receive from the server when you register your application and these are used to verify that you're a Twitter user. The consumer key is how Twitter identifies your application when you send requests. You will need read and write access to post a tweet.
#
# Access tokens are to be used to make API request on your own account's behalf to Twitter and access tokens secret is used to encrypt data from the server.
#
# (More on OAuth: https://techrangers.cdl.ucf.edu/oauth-python-tutorial.php)

# %% [markdown]
# To get consumer token and access token, proceed to following instructions.

# %% [markdown]
# - Create a Twitter account or use your existing one.
# - Go to https://apps.twitter.com/ and log in with your account.
# - Click on Create your app and submit your phone number. A valid phone number is required for the verification process. You can use your mobile phone number for one account only.
# - Fill the form, agree to the terms and conditions, and create your Twitter application.
# - Go to the Keys and Access Tokens tab, save your API key, and API secret and then click on - -
# - Create my access token to obtain the Access token and Access token secret. These four elements will be required to establish a connection with the API.

# %%
url_rest = "https://api.twitter.com/1.1/search/tweets.json" 
url_streaming = "https://stream.twitter.com/1.1/statuses/sample.json"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2. Tweepy library
# - http://www.tweepy.org

# %% [markdown]
# ## 2.1. OAuth
#
# OAuth is Open Authentication Protocol which lets you act on a person's behalf and do things to a website.

# %%
consumer_key        = u'rfbbqTwbEdU7FfhEM5qhWdQSn'
consumer_secret     = u'AXbEXOoIOKIRPPOGXizYCY8zrPpg73aznPwqlbiPBtqyNjX1ZZ'
access_token        = u'50464413-petgMmE6qEKzW33wN7AdMMZODxME9KJSSADyKx99r' 
access_token_secret = u'JBVgy7RcTnHswLyIaOgkLNMRiIsrICBt7fB4CxFRd5Wra'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# `OAuthHandler()` is a function that authorize our app to access Twitter on our behalf. `set_access_token()` initializes access token and token secret. Then your authorization is passed to `.API` function to access Twitter data.

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

#Error handling
try:
  redirect_url = auth.get_authorization_url()
except tweepy.TweepError:
  print ('Error! Failed to get request token.')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 2.2. API Examples

# %% [markdown]
# ### 1. Timeline methods
#
# Timeline methods help us access timeline information of authenticated user or the user specified.

# %% [markdown]
# `.home_timeline()` pulls the most recents statuses, including retweets, on your Twitter timeline and default number of tweets that returns is 20 which can be modified.

# %%
number_tweets=30
pagination=1
public_tweets = api.home_timeline(count=number_tweets, page=pagination)
print("number of tweets:", len(public_tweets))
print("class of the object:", type(public_tweets))
public_tweets[0]._json
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">number of tweets: 30
# class of the object: &lt;class &apos;tweepy.models.ResultSet&apos;&gt;
# <span class="ansired">Out[</span><span class="ansired">40</span><span class="ansired">]: </span>
# {&apos;retweeted&apos;: False,
#  &apos;is_quote_status&apos;: False,
#  &apos;entities&apos;: {&apos;hashtags&apos;: [{&apos;text&apos;: &apos;WorldMetDay&apos;, &apos;indices&apos;: [6, 18]}],
#   &apos;symbols&apos;: [],
#   &apos;user_mentions&apos;: [],
#   &apos;urls&apos;: [{&apos;url&apos;: &apos;https://t.co/bPneeKjP21&apos;,
#     &apos;indices&apos;: [117, 140],
#     &apos;expanded_url&apos;: &apos;https://twitter.com/i/web/status/977189545270824960&apos;,
#     &apos;display_url&apos;: &apos;twitter.com/i/web/status/9…&apos;}]},
#  &apos;in_reply_to_user_id_str&apos;: None,
#  &apos;truncated&apos;: True,
#  &apos;possibly_sensitive&apos;: False,
#  &apos;in_reply_to_user_id&apos;: None,
#  &apos;text&apos;: &apos;Happy #WorldMetDay to this beautiful planet we call home, to the amazing satellite technology we now have to observ… https://t.co/bPneeKjP21&apos;,
#  &apos;user&apos;: {&apos;listed_count&apos;: 347,
#   &apos;default_profile_image&apos;: False,
#   &apos;entities&apos;: {&apos;url&apos;: {&apos;urls&apos;: [{&apos;url&apos;: &apos;https://t.co/Lx8aJSr7DL&apos;,
#       &apos;indices&apos;: [0, 23],
#       &apos;expanded_url&apos;: &apos;http://www.theweatherjunkies.com/single-post/2018/01/31/Mental-Health-in-Meteorology?_amp_=true&amp;__tw&apos;,
#       &apos;display_url&apos;: &apos;theweatherjunkies.com/single-post/20…&apos;}]},
#    &apos;description&apos;: {&apos;urls&apos;: []}},
#   &apos;geo_enabled&apos;: True,
#   &apos;utc_offset&apos;: -14400,
#   &apos;profile_sidebar_border_color&apos;: &apos;FFFFFF&apos;,
#   &apos;id_str&apos;: &apos;26043704&apos;,
#   &apos;has_extended_profile&apos;: True,
#   &apos;profile_background_image_url_https&apos;: &apos;https://pbs.twimg.com/profile_background_images/487467002781384704/z3ij0tMy.jpeg&apos;,
#   &apos;profile_link_color&apos;: &apos;7FDBB6&apos;,
#   &apos;profile_sidebar_fill_color&apos;: &apos;042656&apos;,
#   &apos;time_zone&apos;: &apos;America/New_York&apos;,
#   &apos;favourites_count&apos;: 31282,
#   &apos;friends_count&apos;: 4717,
#   &apos;profile_image_url&apos;: &apos;http://pbs.twimg.com/profile_images/971488796419145728/GqI0iIYj_normal.jpg&apos;,
#   &apos;is_translator&apos;: False,
#   &apos;statuses_count&apos;: 51963,
#   &apos;notifications&apos;: False,
#   &apos;follow_request_sent&apos;: False,
#   &apos;verified&apos;: True,
#   &apos;following&apos;: True,
#   &apos;lang&apos;: &apos;en&apos;,
#   &apos;followers_count&apos;: 6707,
#   &apos;screen_name&apos;: &apos;wx_becks&apos;,
#   &apos;url&apos;: &apos;https://t.co/Lx8aJSr7DL&apos;,
#   &apos;profile_background_tile&apos;: True,
#   &apos;is_translation_enabled&apos;: False,
#   &apos;default_profile&apos;: False,
#   &apos;contributors_enabled&apos;: False,
#   &apos;location&apos;: &apos;Pennsylvania, USA&apos;,
#   &apos;profile_image_url_https&apos;: &apos;https://pbs.twimg.com/profile_images/971488796419145728/GqI0iIYj_normal.jpg&apos;,
#   &apos;protected&apos;: False,
#   &apos;id&apos;: 26043704,
#   &apos;created_at&apos;: &apos;Mon Mar 23 17:17:13 +0000 2009&apos;,
#   &apos;profile_background_color&apos;: &apos;C6E2EE&apos;,
#   &apos;profile_background_image_url&apos;: &apos;http://pbs.twimg.com/profile_background_images/487467002781384704/z3ij0tMy.jpeg&apos;,
#   &apos;description&apos;: &apos;Meteorologist | Product Manager | Emergency Management | Colorado native | Podcast Host (@ElementsPod @IceStationPod) | Nature lover | Cat, dog &amp; moose tweets |&apos;,
#   &apos;profile_use_background_image&apos;: True,
#   &apos;translator_type&apos;: &apos;none&apos;,
#   &apos;profile_text_color&apos;: &apos;6FAF94&apos;,
#   &apos;profile_banner_url&apos;: &apos;https://pbs.twimg.com/profile_banners/26043704/1508270612&apos;,
#   &apos;name&apos;: &apos;Becky DePodwin&apos;},
#  &apos;retweet_count&apos;: 1,
#  &apos;possibly_sensitive_appealable&apos;: False,
#  &apos;id&apos;: 977189545270824960,
#  &apos;in_reply_to_status_id_str&apos;: None,
#  &apos;coordinates&apos;: None,
#  &apos;favorite_count&apos;: 1,
#  &apos;in_reply_to_screen_name&apos;: None,
#  &apos;geo&apos;: None,
#  &apos;source&apos;: &apos;&lt;a href=&quot;https://about.twitter.com/products/tweetdeck&quot; rel=&quot;nofollow&quot;&gt;TweetDeck&lt;/a&gt;&apos;,
#  &apos;in_reply_to_status_id&apos;: None,
#  &apos;place&apos;: None,
#  &apos;contributors&apos;: None,
#  &apos;created_at&apos;: &apos;Fri Mar 23 14:25:17 +0000 2018&apos;,
#  &apos;lang&apos;: &apos;en&apos;,
#  &apos;id_str&apos;: &apos;977189545270824960&apos;,
#  &apos;favorited&apos;: False}
# </div>

# %% [markdown]
# Each one of the JSON attributes is turned into an individual class member in Tweepy’s tweet object. The following is the function that lists all the class members.

# %%
def PrintMembers(obj):
    for attribute in dir(obj):
        
        #We don't want to show built in methods of the class
        if not attribute.startswith('__'):
            print(attribute)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
PrintMembers(public_tweets[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">_api
# _json
# author
# contributors
# coordinates
# created_at
# destroy
# entities
# favorite
# favorite_count
# favorited
# geo
# id
# id_str
# in_reply_to_screen_name
# in_reply_to_status_id
# in_reply_to_status_id_str
# in_reply_to_user_id
# in_reply_to_user_id_str
# is_quote_status
# lang
# parse
# parse_list
# place
# possibly_sensitive
# possibly_sensitive_appealable
# retweet
# retweet_count
# retweeted
# retweets
# source
# source_url
# text
# truncated
# user
# </div>

# %% [markdown]
# We can access each attribute by mounting the class name to the object.

# %%
print("tweet:", public_tweets[0].text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">tweet: How Machines Learn: The Top Four Approaches to ML in Business https://t.co/tacWJEiEWR via @Gigaom
# </div>

# %% [markdown]
# `.user_timeline()` accesses the most recent statuses, including retweets, posted from the specified user. The default value of number of tweets to retrieve can be modified and pagination can be used.

# %%
username="hugobowne"
number_tweets=30
user_tweets=api.user_timeline(username, count=number_tweets)

for tweet in user_tweets:
  print(tweet.text)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">@taraskaduk @rensa_co @storywithdata @DataCamp what did I suggest? :D
# RT @profjsb: @wesmckinn “Senator, we decided to use in-memory dataframes to make it really hard for Pandas to scale to 50M entries on lapto…
# RT @CrimeADay: 18 USC §871 &amp;amp; 879(a) make it a federal crime to threaten to beat up the president or a former president, but not a former vi…
# RT @fchollet: The problem with Facebook is not *just* the loss of your privacy and the fact that it can be used as a totalitarian panoptico…
# Keep yr ears peeled on #DataFramed, the @DataCamp podcast. Many thx to @robinson_es for the connection!
# had a great conversation today w/ @lukasvermeer of @bookingcom about online experimentation, the need for diversity… https://t.co/eY1slZ1vJ2
# @betanalpha i don&apos;t know if it&apos;s entirely true but it&apos;s a pretty narrow distribution around the statement.
# @jsbois @betanalpha @DataCamp one of mike&apos;s superpowers is to listen kindly and patiently and allow you to express… https://t.co/NgFN9hb3bJ
# @jsbois @betanalpha @DataCamp it was a wild ride that i can&apos;t wait to share !
# RT @svfitzpatrick: This is masterful, and premised on the notion that substantive Indigenous constitutional recognition, as proposed in the…
# @betanalpha &quot;nothing if not adequate&quot;
# @LorenaABarba what a wonderful group of people!
# @MilesMcBain @betanalpha @DataCamp thanks mate!
# i currently feel like i bit off a bit more than i can chew w/ a weekly 1hour podcast
# I had a wonderful conversation w/ @betanalpha for #DataFramed, the @DataCamp podcast, about robust data science w/… https://t.co/0pND9piAuB
# @flosterzo @GooglePlayMusic we&apos;re on spotify. all our episodes are on soundcloud and also here:… https://t.co/iMCBSRkzLS
# @chatwithtraders thanks! Will do. Would be great to chat.
# @kn_neeraj @antgoldbloom @kaggle @DataCamp the podcasts app works fine for me. what happens if you try iTunes, over… https://t.co/cX6MrxxJSb
# cc @DataCamp . Thanks, Marta! https://t.co/Y2cRnP17qV
# @kn_neeraj @antgoldbloom @kaggle @DataCamp aaaaah the iPhone app &quot;podcasts&quot;? looking into it
# @kn_neeraj @antgoldbloom @kaggle @DataCamp whoa! thanks for the heads up. I&apos;m not having an issue on iTunes or over… https://t.co/VZOI8oiPFL
# RT @DataCamp: How can data science be leveraged to inform business decisions around all the text data available? And what can all the open…
# @SSusanbayes @antgoldbloom @kaggle @DataCamp thanks, Susan, that means a lot!
# RT @defsophiaray: I&apos;ve been using computers for 23 years and I have never once intended to copy/paste the random ass style of whatever text…
# @krassenstein I believe it but would you mind including a source?
# RT @fchollet: https://t.co/fw1QN9UAcJ
# I just signed the Data Practices Manifesto, which describes the most effective, ethical, and modern approach to dat… https://t.co/asvXETBGz0
# https://t.co/xWUI2KMW5E
# @fryan open source tools such as &#96;pandas&#96; (seen in screenshot, developed by wes, among many others) can be used for… https://t.co/5QJcvn3nVW
# whoa https://t.co/3qazgGmAUl
# I just had a great conversation w/ @antgoldbloom , CEO of @kaggle , for #DataFramed, the @DataCamp podcast. Keep yo… https://t.co/MGNnvzEFKp
# </div>

# %% [markdown]
# ### 2. User methods
#
# User methods are designed to work with user and followers information.

# %% [markdown]
# ####Extracting followers list
#
# `.followers()` returns information of people who follows specified user and the results are ordered in the most recent followers first in
# which they're added 20 at a time. To mount more followers list, we need to use `cursor` to navigate to the next requests.

# %%
followers=api.followers(username)
len(followers)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">41</span><span class="ansired">]: </span>20
# </div>

# %% [markdown]
# Following function can be used to pass the next cursor to the API and extract followers list automatically. After certain number of follower extraction, the extraction reaches its limit and takes time to sleep.

# %%
import json
import time

followers=[]
def process_or_store_followers(follower):
    followers.append(follower)
    
def limit_handled(cursor):
  while True:
    try:
      yield cursor.next()
    except tweepy.RateLimitError:
      time.sleep(15 * 60)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
followers_count=0
user_name="hugobowne"
for follower in limit_handled(tweepy.Cursor(api.followers, 
                              screen_name=user_name, 
                              rpp=100,
                             ).items()):  
  process_or_store_followers(follower._json)
  followers_count+=1
  print("Downloaded {0} followers".format(followers_count))

# %% [markdown]
# Display `followers` list.

# %%
followers
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>
# [{&apos;follow_request_sent&apos;: False,
#   &apos;geo_enabled&apos;: False,
#   &apos;has_extended_profile&apos;: True,
#   &apos;profile_background_image_url_https&apos;: &apos;https://abs.twimg.com/images/themes/theme1/bg.png&apos;,
#   &apos;time_zone&apos;: None,
#   &apos;favourites_count&apos;: 67,
#   &apos;friends_count&apos;: 25,
#   &apos;profile_image_url&apos;: &apos;http://pbs.twimg.com/profile_images/909449654328107008/UkB9UQsF_normal.jpg&apos;,
#   &apos;is_translator&apos;: False,
#   &apos;statuses_count&apos;: 53,
#   &apos;blocked_by&apos;: False,
#   &apos;verified&apos;: False,
#   &apos;lang&apos;: &apos;en&apos;,
#   &apos;followers_count&apos;: 40,
#   &apos;url&apos;: &apos;https://t.co/hOehKHbjIK&apos;,
#   &apos;profile_background_tile&apos;: False,
#   &apos;live_following&apos;: False,
#   &apos;contributors_enabled&apos;: False,
#   &apos;profile_banner_url&apos;: &apos;https://pbs.twimg.com/profile_banners/898621482187620354/1503085226&apos;,
#   &apos;protected&apos;: False,
#   &apos;id&apos;: 898621482187620354,
#   &apos;profile_background_color&apos;: &apos;000000&apos;,
#   &apos;description&apos;: &apos;HS Coding Teacher👨\u200d💻⌨️&apos;,
#   &apos;profile_use_background_image&apos;: False,
#   &apos;blocking&apos;: False,
#   &apos;name&apos;: &apos;William Masse&apos;,
#   &apos;listed_count&apos;: 2,
#   &apos;default_profile_image&apos;: False,
#   &apos;entities&apos;: {&apos;url&apos;: {&apos;urls&apos;: [{&apos;url&apos;: &apos;https://t.co/hOehKHbjIK&apos;,
#       &apos;indices&apos;: [0, 23],
#       &apos;expanded_url&apos;: &apos;http://blackstonevalleyprep.org/&apos;,
#       &apos;display_url&apos;: &apos;blackstonevalleyprep.org&apos;}]},
#    &apos;description&apos;: {&apos;urls&apos;: []}},
#   &apos;is_translation_enabled&apos;: False,
#   &apos;utc_offset&apos;: None,
#   &apos;profile_sidebar_border_color&apos;: &apos;000000&apos;,
#   &apos;id_str&apos;: &apos;898621482187620354&apos;,
#   &apos;profile_link_color&apos;: &apos;6E8EC0&apos;,
#   &apos;default_profile&apos;: False,
#   &apos;profile_sidebar_fill_color&apos;: &apos;000000&apos;,
#   &apos;screen_name&apos;: &apos;masse_bvp&apos;,
#   &apos;muting&apos;: False,
#   &apos;location&apos;: &apos;Cumberland, RI&apos;,
#   &apos;profile_image_url_https&apos;: &apos;https://pbs.twimg.com/profile_images/909449654328107008/UkB9UQsF_normal.jpg&apos;,
#   &apos;created_at&apos;: &apos;Fri Aug 18 19:03:51 +0000 2017&apos;,
#   &apos;notifications&apos;: False,
#   &apos;status&apos;: {&apos;retweeted&apos;: False,
#    &apos;is_quote_status&apos;: False,
#    &apos;entities&apos;: {&apos;hashtags&apos;: [],
#     &apos;symbols&apos;: [],
#     &apos;user_mentions&apos;: [{&apos;screen_name&apos;: &apos;timthemathman&apos;,
#       &apos;id_str&apos;: &apos;761557904&apos;,
#       &apos;indices&apos;: [0, 14],
#       &apos;name&apos;: &apos;Tim Howarth&apos;,
#       &apos;id&apos;: 761557904},
#      {&apos;screen_name&apos;: &apos;BVPBio&apos;,
#       &apos;id_str&apos;: &apos;898379857561780226&apos;,
#       &apos;indices&apos;: [15, 22],
#       &apos;name&apos;: &apos;Becky Jackson&apos;,
#       &apos;id&apos;: 898379857561780226},
#      {&apos;screen_name&apos;: &apos;michaela_keegan&apos;,
#       &apos;id_str&apos;: &apos;790254942405664769&apos;,
#       &apos;indices&apos;: [23, 39],
#       &apos;name&apos;: &apos;Michaela Keegan&apos;,
#       &apos;id&apos;: 790254942405664769},
#      {&apos;screen_name&apos;: &apos;davejose&apos;,
#       &apos;id_str&apos;: &apos;16139345&apos;,
#       &apos;indices&apos;: [40, 49],
#       &apos;name&apos;: &apos;David Jose&apos;,
#       &apos;id&apos;: 16139345}],
#     &apos;urls&apos;: []},
#    &apos;in_reply_to_user_id_str&apos;: &apos;761557904&apos;,
#    &apos;truncated&apos;: False,
#    &apos;in_reply_to_user_id&apos;: 761557904,
#    &apos;text&apos;: &apos;@timthemathman @BVPBio @michaela_keegan @davejose You’re not watching?? This will reflect poorly on your annual performance review&apos;,
#    &apos;retweet_count&apos;: 0,
#    &apos;id&apos;: 965787128037769216,
#    &apos;in_reply_to_status_id_str&apos;: &apos;965786510384607233&apos;,
#    &apos;coordinates&apos;: None,
#    &apos;favorite_count&apos;: 2,
#    &apos;in_reply_to_screen_name&apos;: &apos;timthemathman&apos;,
#    &apos;geo&apos;: None,
#    &apos;source&apos;: &apos;&lt;a href=&quot;http://twitter.com/download/iphone&quot; rel=&quot;nofollow&quot;&gt;Twitter for iPhone&lt;/a&gt;&apos;,
#    &apos;in_reply_to_status_id&apos;: 965786510384607233,
#    &apos;place&apos;: None,
#    &apos;contributors&apos;: None,
#    &apos;created_at&apos;: &apos;Tue Feb 20 03:16:09 +0000 2018&apos;,
#    &apos;lang&apos;: &apos;en&apos;,
#    &apos;id_str&apos;: &apos;965787128037769216&apos;,
#    &apos;favorited&apos;: False},
#   &apos;following&apos;: False,
#   &apos;translator_type&apos;: &apos;none&apos;,
#   &apos;profile_text_color&apos;: &apos;000000&apos;,
#   &apos;profile_background_image_url&apos;: &apos;http://abs.twimg.com/images/themes/theme1/bg.png&apos;},
#  {&apos;follow_request_sent&apos;: False,
#   &apos;geo_enabled&apos;: False,
#   &apos;has_extended_profile&apos;: False,
#   &apos;profile_background_image_url_https&apos;: &apos;https://abs.twimg.com/images/themes/theme1/bg.png&apos;,
#   &apos;time_zone&apos;: None,
#   &apos;favourites_count&apos;: 1,
#   &apos;friends_count&apos;: 27,
#   &apos;profile_image_url&apos;: &apos;http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png&apos;,
#   &apos;is_translator&apos;: False,
#   &apos;statuses_count&apos;: 0,
#   &apos;blocked_by&apos;: False,
#   &apos;verified&apos;: False,
#   &apos;lang&apos;: &apos;da&apos;,
#   &apos;followers_count&apos;: 1,
#   &apos;url&apos;: None,
#   &apos;profile_background_tile&apos;: False,
#   &apos;live_following&apos;: False,
#   &apos;contributors_enabled&apos;: False,
#   &apos;protected&apos;: False,
#   &apos;id&apos;: 1639889605,
#   &apos;profile_background_color&apos;: &apos;C0DEED&apos;,
#   &apos;description&apos;: &apos;&apos;,
#   &apos;profile_use_background_image&apos;: True,
#   &apos;blocking&apos;: False,
#   &apos;name&apos;: &apos;Søren Skotte&apos;,
#   &apos;listed_count&apos;: 0,
#   &apos;default_profile_image&apos;: True,
#   &apos;entities&apos;: {&apos;description&apos;: {&apos;urls&apos;: []}},
#   &apos;is_translation_enabled&apos;: False,
#   &apos;utc_offset&apos;: None,
#   &apos;profile_sidebar_border_color&apos;: &apos;C0DEED&apos;,
#   &apos;id_str&apos;: &apos;1639889605&apos;,
#   &apos;profile_link_color&apos;: &apos;1DA1F2&apos;,
#   &apos;default_profile&apos;: True,
#   &apos;profile_sidebar_fill_color&apos;: &apos;DDEEF6&apos;,
#   &apos;screen_name&apos;: &apos;Soren_Skotte&apos;,
#   &apos;muting&apos;: False,
#   &apos;location&apos;: &apos;&apos;,
#   &apos;profile_image_url_https&apos;: &apos;https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png&apos;,
#   &apos;created_at&apos;: &apos;Fri Aug 02 07:37:29 +0000 2013&apos;,
#   &apos;notifications&apos;: False,
#   &apos;following&apos;: False,
#   &apos;translator_type&apos;: &apos;none&apos;,
#   &apos;profile_text_color&apos;: &apos;333333&apos;,
#   &apos;profile_background_image_url&apos;: &apos;http://abs.twimg.com/images/themes/theme1/bg.png&apos;},
#  {&apos;follow_request_sent&apos;: False,
#   &apos;geo_enabled&apos;: True,
#   &apos;has_extended_profile&apos;: False,
#   &apos;profile_background_image_url_https&apos;: &apos;https://pbs.twimg.com/profile_background_images/615957350/1utozf7mwp1yyml2ygg0.jpeg&apos;,
#   &apos;time_zone&apos;: &apos;London&apos;,
#   &apos;favourites_count&apos;: 265,
#   &apos;friends_count&apos;: 271,
#   &apos;profile_image_url&apos;: &apos;http://pbs.twimg.com/profile_images/9239887271600660

# %%
print(len(followers))
followers[1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">280
# <span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>
# {&apos;follow_request_sent&apos;: False,
#  &apos;geo_enabled&apos;: False,
#  &apos;has_extended_profile&apos;: False,
#  &apos;profile_background_image_url_https&apos;: &apos;https://abs.twimg.com/images/themes/theme1/bg.png&apos;,
#  &apos;time_zone&apos;: None,
#  &apos;favourites_count&apos;: 1,
#  &apos;friends_count&apos;: 27,
#  &apos;profile_image_url&apos;: &apos;http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png&apos;,
#  &apos;is_translator&apos;: False,
#  &apos;statuses_count&apos;: 0,
#  &apos;blocked_by&apos;: False,
#  &apos;verified&apos;: False,
#  &apos;lang&apos;: &apos;da&apos;,
#  &apos;followers_count&apos;: 1,
#  &apos;url&apos;: None,
#  &apos;profile_background_tile&apos;: False,
#  &apos;live_following&apos;: False,
#  &apos;contributors_enabled&apos;: False,
#  &apos;protected&apos;: False,
#  &apos;id&apos;: 1639889605,
#  &apos;profile_background_color&apos;: &apos;C0DEED&apos;,
#  &apos;description&apos;: &apos;&apos;,
#  &apos;profile_use_background_image&apos;: True,
#  &apos;blocking&apos;: False,
#  &apos;name&apos;: &apos;Søren Skotte&apos;,
#  &apos;listed_count&apos;: 0,
#  &apos;default_profile_image&apos;: True,
#  &apos;entities&apos;: {&apos;description&apos;: {&apos;urls&apos;: []}},
#  &apos;is_translation_enabled&apos;: False,
#  &apos;utc_offset&apos;: None,
#  &apos;profile_sidebar_border_color&apos;: &apos;C0DEED&apos;,
#  &apos;id_str&apos;: &apos;1639889605&apos;,
#  &apos;profile_link_color&apos;: &apos;1DA1F2&apos;,
#  &apos;default_profile&apos;: True,
#  &apos;profile_sidebar_fill_color&apos;: &apos;DDEEF6&apos;,
#  &apos;screen_name&apos;: &apos;Soren_Skotte&apos;,
#  &apos;muting&apos;: False,
#  &apos;location&apos;: &apos;&apos;,
#  &apos;profile_image_url_https&apos;: &apos;https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png&apos;,
#  &apos;created_at&apos;: &apos;Fri Aug 02 07:37:29 +0000 2013&apos;,
#  &apos;notifications&apos;: False,
#  &apos;following&apos;: False,
#  &apos;translator_type&apos;: &apos;none&apos;,
#  &apos;profile_text_color&apos;: &apos;333333&apos;,
#  &apos;profile_background_image_url&apos;: &apos;http://abs.twimg.com/images/themes/theme1/bg.png&apos;}
# </div>

# %% [markdown]
# Saving extracted followers list as `pickle` file.

# %%
import pickle

pickle.dump(followers, open( "/dbfs/FileStore/tmp/followers.pkl", "wb" ) )

# %%
# %sh ls -lh /dbfs/FileStore/tmp/*.pkl

# %% [markdown]
# Loading saved pickle file as `hugo_followers`

# %%
import pickle

hugo_followers = pickle.load(open( "/dbfs/FileStore/tmp/followers.pkl", "rb" ) )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
len(hugo_followers), type(hugo_followers), type(hugo_followers[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>(1500, list, dict)
# </div>

# %%
hugo_followers[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>
# {&apos;follow_request_sent&apos;: False,
#  &apos;geo_enabled&apos;: True,
#  &apos;has_extended_profile&apos;: False,
#  &apos;profile_background_image_url_https&apos;: &apos;https://abs.twimg.com/images/themes/theme1/bg.png&apos;,
#  &apos;profile_use_background_image&apos;: True,
#  &apos;favourites_count&apos;: 90,
#  &apos;friends_count&apos;: 161,
#  &apos;profile_image_url&apos;: &apos;http://pbs.twimg.com/profile_images/879407628593618945/mdxC7ArE_normal.jpg&apos;,
#  &apos;is_translator&apos;: False,
#  &apos;statuses_count&apos;: 36,
#  &apos;blocked_by&apos;: False,
#  &apos;verified&apos;: False,
#  &apos;lang&apos;: &apos;es&apos;,
#  &apos;followers_count&apos;: 61,
#  &apos;url&apos;: None,
#  &apos;profile_background_tile&apos;: False,
#  &apos;live_following&apos;: False,
#  &apos;contributors_enabled&apos;: False,
#  &apos;protected&apos;: False,
#  &apos;id&apos;: 11671242,
#  &apos;profile_background_color&apos;: &apos;C0DEED&apos;,
#  &apos;description&apos;: &apos;&apos;,
#  &apos;blocking&apos;: False,
#  &apos;name&apos;: &apos;Rodo&apos;,
#  &apos;listed_count&apos;: 0,
#  &apos;default_profile_image&apos;: False,
#  &apos;entities&apos;: {&apos;description&apos;: {&apos;urls&apos;: []}},
#  &apos;is_translation_enabled&apos;: False,
#  &apos;utc_offset&apos;: 3600,
#  &apos;profile_sidebar_border_color&apos;: &apos;C0DEED&apos;,
#  &apos;id_str&apos;: &apos;11671242&apos;,
#  &apos;profile_link_color&apos;: &apos;1DA1F2&apos;,
#  &apos;default_profile&apos;: True,
#  &apos;profile_sidebar_fill_color&apos;: &apos;DDEEF6&apos;,
#  &apos;screen_name&apos;: &apos;phoenixrlv&apos;,
#  &apos;muting&apos;: False,
#  &apos;time_zone&apos;: &apos;Madrid&apos;,
#  &apos;location&apos;: &apos;Valencia-España&apos;,
#  &apos;profile_image_url_https&apos;: &apos;https://pbs.twimg.com/profile_images/879407628593618945/mdxC7ArE_normal.jpg&apos;,
#  &apos;created_at&apos;: &apos;Sun Dec 30 23:19:08 +0000 2007&apos;,
#  &apos;notifications&apos;: False,
#  &apos;status&apos;: {&apos;retweeted&apos;: False,
#   &apos;is_quote_status&apos;: False,
#   &apos;entities&apos;: {&apos;symbols&apos;: [],
#    &apos;urls&apos;: [],
#    &apos;user_mentions&apos;: [{&apos;screen_name&apos;: &apos;ActualidadRT&apos;,
#      &apos;id_str&apos;: &apos;100731315&apos;,
#      &apos;indices&apos;: [0, 13],
#      &apos;name&apos;: &apos;RT en Español&apos;,
#      &apos;id&apos;: 100731315}],
#    &apos;hashtags&apos;: []},
#   &apos;in_reply_to_user_id_str&apos;: &apos;100731315&apos;,
#   &apos;truncated&apos;: False,
#   &apos;in_reply_to_user_id&apos;: 100731315,
#   &apos;text&apos;: &apos;@ActualidadRT Perú&apos;,
#   &apos;retweet_count&apos;: 0,
#   &apos;in_reply_to_status_id&apos;: 970773456336846849,
#   &apos;in_reply_to_status_id_str&apos;: &apos;970773456336846849&apos;,
#   &apos;lang&apos;: &apos;es&apos;,
#   &apos;favorite_count&apos;: 0,
#   &apos;place&apos;: {&apos;attributes&apos;: {},
#    &apos;place_type&apos;: &apos;city&apos;,
#    &apos;country_code&apos;: &apos;PE&apos;,
#    &apos;url&apos;: &apos;https://api.twitter.com/1.1/geo/id/005bf2190435cf68.json&apos;,
#    &apos;full_name&apos;: &apos;Santiago de Surco, Peru&apos;,
#    &apos;country&apos;: &apos;Peru&apos;,
#    &apos;id&apos;: &apos;005bf2190435cf68&apos;,
#    &apos;contained_within&apos;: [],
#    &apos;name&apos;: &apos;Santiago de Surco&apos;,
#    &apos;bounding_box&apos;: {&apos;type&apos;: &apos;Polygon&apos;,
#     &apos;coordinates&apos;: [[[-77.0154710434534, -12.1760119798814],
#       [-76.9473658792884, -12.1760119798814],
#       [-76.9473658792884, -12.0771410379137],
#       [-77.0154710434534, -12.0771410379137]]]}},
#   &apos;geo&apos;: None,
#   &apos;source&apos;: &apos;&lt;a href=&quot;http://twitter.com/download/android&quot; rel=&quot;nofollow&quot;&gt;Twitter for Android&lt;/a&gt;&apos;,
#   &apos;id&apos;: 971163994701615104,
#   &apos;in_reply_to_screen_name&apos;: &apos;ActualidadRT&apos;,
#   &apos;contributors&apos;: None,
#   &apos;created_at&apos;: &apos;Tue Mar 06 23:21:54 +0000 2018&apos;,
#   &apos;coordinates&apos;: None,
#   &apos;id_str&apos;: &apos;971163994701615104&apos;,
#   &apos;favorited&apos;: False},
#  &apos;following&apos;: False,
#  &apos;translator_type&apos;: &apos;none&apos;,
#  &apos;profile_text_color&apos;: &apos;333333&apos;,
#  &apos;profile_background_image_url&apos;: &apos;http://abs.twimg.com/images/themes/theme1/bg.png&apos;}
# </div>

# %%
hugo_followers[0].keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">42</span><span class="ansired">]: </span>dict_keys([&apos;follow_request_sent&apos;, &apos;geo_enabled&apos;, &apos;has_extended_profile&apos;, &apos;profile_background_image_url_https&apos;, &apos;profile_use_background_image&apos;, &apos;favourites_count&apos;, &apos;friends_count&apos;, &apos;profile_image_url&apos;, &apos;is_translator&apos;, &apos;statuses_count&apos;, &apos;blocked_by&apos;, &apos;verified&apos;, &apos;lang&apos;, &apos;followers_count&apos;, &apos;url&apos;, &apos;profile_background_tile&apos;, &apos;live_following&apos;, &apos;contributors_enabled&apos;, &apos;protected&apos;, &apos;id&apos;, &apos;profile_background_color&apos;, &apos;description&apos;, &apos;blocking&apos;, &apos;name&apos;, &apos;listed_count&apos;, &apos;default_profile_image&apos;, &apos;entities&apos;, &apos;is_translation_enabled&apos;, &apos;utc_offset&apos;, &apos;profile_sidebar_border_color&apos;, &apos;id_str&apos;, &apos;profile_link_color&apos;, &apos;default_profile&apos;, &apos;profile_sidebar_fill_color&apos;, &apos;screen_name&apos;, &apos;muting&apos;, &apos;time_zone&apos;, &apos;location&apos;, &apos;profile_image_url_https&apos;, &apos;created_at&apos;, &apos;notifications&apos;, &apos;status&apos;, &apos;following&apos;, &apos;translator_type&apos;, &apos;profile_text_color&apos;, &apos;profile_background_image_url&apos;])
# </div>

# %% [markdown]
# We can use `pandas` library to create dataframe from list of dictionaries by assigning column names to `columns` parameter.

# %%
import pandas as pd

col_names=['name', 'screen_name', 'followers_count', 'friends_count', 'favourites_count', 
           'status_count','created_at','language','location']
hugo_follower_data = pd.DataFrame.from_records(hugo_followers, columns=col_names)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hugo_follower_data.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>
#                  name     screen_name  followers_count  friends_count  \
# 0                Rodo      phoenixrlv               61            161
# 1     Anders Hosbjerg  AndersHosbjerg               54            470
# 2  Alexander Weidauer    alexweidauer              902            313
# 3      Silicon Armada   SiliconArmada            43208          45881
# 4     Semiha Demirbas  semihademirbas              186            622
#
#    favourites_count  status_count                      created_at  language  \
# 0                90           NaN  Sun Dec 30 23:19:08 +0000 2007       NaN
# 1               317           NaN  Wed Jun 12 10:33:47 +0000 2013       NaN
# 2               488           NaN  Mon Mar 28 12:39:31 +0000 2011       NaN
# 3              3739           NaN  Wed Dec 11 10:54:32 +0000 2013       NaN
# 4                46           NaN  Mon Jul 04 13:55:29 +0000 2011       NaN
#
#                    location
# 0           Valencia-España
# 1
# 2           Berlin, Germany
# 3  Global - Born in Ireland
# 4
# </div>

# %% [markdown]
# Saving `hugo_follower_data` dataframe as pickle file.

# %%
import pickle

pickle.dump(hugo_follower_data, open( "/dbfs/FileStore/tmp/hugo_follower_data.pkl", "wb" ) )

# %% [markdown]
# ####Extracting friends list
#
# `.friends()` returns information of users that specified user is following. It returns the most recent following first in which they're added 20 at a time. To mount more friends list, `cursor` is used to navigate to the next requests.

# %%
import json
import time

following=[]
def process_or_store_following(friend):
    following.append(friend)
    
def limit_handled(cursor):
  while True:
    try:
      yield cursor.next()
    except tweepy.RateLimitError:
      time.sleep(15 * 60)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
friend_count=0
user_name="hugobowne"
for friend in limit_handled(tweepy.Cursor(api.friends, 
                                          screen_name=user_name, 
                                          rpp=100
                                         ).items()):  
  process_or_store_following(friend._json)
  friend_count+=1
  print("Downloaded {0} friends".format(friend_count))

# %% [markdown]
# Save `following` as `pickle` file to get easy access to the data.

# %%
import pickle

pickle.dump(following, open( "/dbfs/FileStore/tmp/following.pkl", "wb" ) )

# %%
# %sh ls -lh /dbfs/FileStore/tmp/*.pkl

# %% [markdown]
# Loading saved `pickle` file.

# %%
import pickle

hugo_following = pickle.load(open( "/dbfs/FileStore/tmp/following.pkl", "rb" ) )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
len(hugo_following), type(hugo_following), type(hugo_following[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">23</span><span class="ansired">]: </span>(544, list, dict)
# </div>

# %%
hugo_following[0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>
# {&apos;follow_request_sent&apos;: False,
#  &apos;geo_enabled&apos;: False,
#  &apos;has_extended_profile&apos;: False,
#  &apos;profile_background_image_url_https&apos;: &apos;https://abs.twimg.com/images/themes/theme1/bg.png&apos;,
#  &apos;profile_use_background_image&apos;: False,
#  &apos;favourites_count&apos;: 210,
#  &apos;friends_count&apos;: 1212,
#  &apos;profile_image_url&apos;: &apos;http://pbs.twimg.com/profile_images/903598528508899329/3Qj4AU6__normal.jpg&apos;,
#  &apos;is_translator&apos;: False,
#  &apos;statuses_count&apos;: 610,
#  &apos;blocked_by&apos;: False,
#  &apos;verified&apos;: False,
#  &apos;lang&apos;: &apos;en&apos;,
#  &apos;followers_count&apos;: 1427,
#  &apos;url&apos;: &apos;https://t.co/2PZWaUHt9e&apos;,
#  &apos;profile_background_tile&apos;: False,
#  &apos;live_following&apos;: False,
#  &apos;contributors_enabled&apos;: False,
#  &apos;profile_banner_url&apos;: &apos;https://pbs.twimg.com/profile_banners/2839825685/1517558670&apos;,
#  &apos;protected&apos;: False,
#  &apos;id&apos;: 2839825685,
#  &apos;profile_background_color&apos;: &apos;000000&apos;,
#  &apos;description&apos;: &apos;#Opensource conversational #AI to build intelligent applications. #ML-based #NLU and dialogue management  🤖 Join the #community https://t.co/r8F2aUajFp&apos;,
#  &apos;blocking&apos;: False,
#  &apos;name&apos;: &apos;Rasa&apos;,
#  &apos;listed_count&apos;: 77,
#  &apos;default_profile_image&apos;: False,
#  &apos;entities&apos;: {&apos;url&apos;: {&apos;urls&apos;: [{&apos;url&apos;: &apos;https://t.co/2PZWaUHt9e&apos;,
#      &apos;indices&apos;: [0, 23],
#      &apos;expanded_url&apos;: &apos;https://rasa.com&apos;,
#      &apos;display_url&apos;: &apos;rasa.com&apos;}]},
#   &apos;description&apos;: {&apos;urls&apos;: [{&apos;url&apos;: &apos;https://t.co/r8F2aUajFp&apos;,
#      &apos;indices&apos;: [128, 151],
#      &apos;expanded_url&apos;: &apos;https://gitter.im/RasaHQ/home&apos;,
#      &apos;display_url&apos;: &apos;gitter.im/RasaHQ/home&apos;}]}},
#  &apos;is_translation_enabled&apos;: False,
#  &apos;utc_offset&apos;: 3600,
#  &apos;profile_sidebar_border_color&apos;: &apos;000000&apos;,
#  &apos;id_str&apos;: &apos;2839825685&apos;,
#  &apos;profile_link_color&apos;: &apos;5A17EE&apos;,
#  &apos;default_profile&apos;: False,
#  &apos;profile_sidebar_fill_color&apos;: &apos;000000&apos;,
#  &apos;screen_name&apos;: &apos;Rasa_HQ&apos;,
#  &apos;muting&apos;: False,
#  &apos;time_zone&apos;: &apos;Berlin&apos;,
#  &apos;location&apos;: &apos;Berlin, Germany&apos;,
#  &apos;profile_image_url_https&apos;: &apos;https://pbs.twimg.com/profile_images/903598528508899329/3Qj4AU6__normal.jpg&apos;,
#  &apos;created_at&apos;: &apos;Tue Oct 21 12:50:32 +0000 2014&apos;,
#  &apos;notifications&apos;: False,
#  &apos;status&apos;: {&apos;retweeted&apos;: False,
#   &apos;is_quote_status&apos;: False,
#   &apos;entities&apos;: {&apos;symbols&apos;: [],
#    &apos;urls&apos;: [],
#    &apos;user_mentions&apos;: [{&apos;screen_name&apos;: &apos;hugobowne&apos;,
#      &apos;id_str&apos;: &apos;1092509048&apos;,
#      &apos;indices&apos;: [3, 13],
#      &apos;name&apos;: &apos;Hugo Bowne-Anderson&apos;,
#      &apos;id&apos;: 1092509048},
#     {&apos;screen_name&apos;: &apos;DataCamp&apos;,
#      &apos;id_str&apos;: &apos;1568606814&apos;,
#      &apos;indices&apos;: [29, 38],
#      &apos;name&apos;: &apos;DataCamp&apos;,
#      &apos;id&apos;: 1568606814},
#     {&apos;screen_name&apos;: &apos;alanmnichol&apos;,
#      &apos;id_str&apos;: &apos;2306462901&apos;,
#      &apos;indices&apos;: [97, 109],
#      &apos;name&apos;: &apos;Alan Nichol&apos;,
#      &apos;id&apos;: 2306462901},
#     {&apos;screen_name&apos;: &apos;Rasa_HQ&apos;,
#      &apos;id_str&apos;: &apos;2839825685&apos;,
#      &apos;indices&apos;: [113, 121],
#      &apos;name&apos;: &apos;Rasa&apos;,
#      &apos;id&apos;: 2839825685}],
#    &apos;hashtags&apos;: []},
#   &apos;in_reply_to_user_id_str&apos;: None,
#   &apos;truncated&apos;: False,
#   &apos;in_reply_to_user_id&apos;: None,
#   &apos;text&apos;: &apos;RT @hugobowne: Check out our @DataCamp *building chatbots in python* course, with the inimitable @alanmnichol of @Rasa_HQ infamy. This was…&apos;,
#   &apos;retweet_count&apos;: 10,
#   &apos;in_reply_to_status_id&apos;: None,
#   &apos;in_reply_to_status_id_str&apos;: None,
#   &apos;lang&apos;: &apos;en&apos;,
#   &apos;favorite_count&apos;: 0,
#   &apos;place&apos;: None,
#   &apos;geo&apos;: None,
#   &apos;contributors&apos;: None,
#   &apos;source&apos;: &apos;&lt;a href=&quot;http://twitter.com/download/iphone&quot; rel=&quot;nofollow&quot;&gt;Twitter for iPhone&lt;/a&gt;&apos;,
#   &apos;id&apos;: 973838926103416832,
#   &apos;in_reply_to_screen_name&apos;: None,
#   &apos;retweeted_status&apos;: {&apos;retweeted&apos;: False,
#    &apos;is_quote_status&apos;: False,
#    &apos;entities&apos;: {&apos;symbols&apos;: [],
#     &apos;urls&apos;: [{&apos;url&apos;: &apos;https://t.co/GOBwsi4ePV&apos;,
#       &apos;indices&apos;: [116, 139],
#       &apos;expanded_url&apos;: &apos;https://twitter.com/i/web/status/973680422063255553&apos;,
#       &apos;display_url&apos;: &apos;twitter.com/i/web/status/9…&apos;}],
#     &apos;user_mentions&apos;: [{&apos;screen_name&apos;: &apos;DataCamp&apos;,
#       &apos;id_str&apos;: &apos;1568606814&apos;,
#       &apos;indices&apos;: [14, 23],
#       &apos;name&apos;: &apos;DataCamp&apos;,
#       &apos;id&apos;: 1568606814},
#      {&apos;screen_name&apos;: &apos;alanmnichol&apos;,
#       &apos;id_str&apos;: &apos;2306462901&apos;,
#       &apos;indices&apos;: [82, 94],
#       &apos;name&apos;: &apos;Alan Nichol&apos;,
#       &apos;id&apos;: 2306462901},
#      {&apos;screen_name&apos;: &apos;Rasa_HQ&apos;,
#       &apos;id_str&apos;: &apos;2839825685&apos;,
#       &apos;indices&apos;: [98, 106],
#       &apos;name&apos;: &apos;Rasa&apos;,
#       &apos;id&apos;: 2839825685}],
#     &apos;hashtags&apos;: []},
#    &apos;in_reply_to_user_id_str&apos;: None,
#    &apos;truncated&apos;: True,
#    &apos;possibly_sensitive&apos;: False,
#    &apos;in_reply_to_user_id&apos;: None,
#    &apos;text&apos;: &apos;Check out our @DataCamp *building chatbots in python* course, with the inimitable @alanmnichol of @Rasa_HQ infamy.… https://t.co/GOBwsi4ePV&apos;,
#    &apos;retweet_count&apos;: 10,
#    &apos;in_reply_to_status_id&apos;: None,
#    &apos;in_reply_to_status_id_str&apos;: None,
#    &apos;lang&apos;: &apos;en&apos;,
#    &apos;favorite_count&apos;: 27,
#    &apos;place&apos;: None,
#    &apos;geo&apos;: None,
#    &apos;source&apos;: &apos;&lt;a href=&quot;http://twitter.com&quot; rel=&quot;nofollow&quot;&gt;Twitter Web Client&lt;/a&gt;&apos;,
#    &apos;id&apos;: 973680422063255553,
#    &apos;in_reply_to_screen_name&apos;: None,
#    &apos;contributors&apos;: None,
#    &apos;created_at&apos;: &apos;Tue Mar 13 22:01:17 +0000 2018&apos;,
#    &apos;coordinates&apos;: None,
#    &apos;id_str&apos;: &apos;973680422063255553&apos;,
#    &apos;favorited&apos;: False},
#   &apos;created_at&apos;: &apos;Wed Mar 14 08:31:07 +0000 2018&apos;,
#   &apos;coordinates&apos;: None,
#   &apos;id_str&apos;: &apos;973838926103416832&apos;,
#   &apos;favorited&apos;: False},
#  &apos;following&apos;: False,
#  &apos;translator_type&apos;: &apos;regular&apos;,
#  &apos;profile_text_color&apos;: &apos;000000&apos;,
#  &apos;profile_background_image_url&apos;: &apos;http://abs.twimg.com/images/themes/theme1/bg.png&apos;}
# </div>

# %% [markdown]
# We can use `pandas` library to create dataframe from list of dictionary by assigning column names to `columns` parameter.

# %%
import pandas as pd

col_names=['name', 'screen_name','followers_count', 'friends_count', 'favourites_count', 
           'status_count','created_at','language','location','id']
hugo_following_data = pd.DataFrame.from_records(hugo_following, columns=col_names)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hugo_following_data.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">26</span><span class="ansired">]: </span>(544, 10)
# </div>

# %% [markdown]
# And save the dataframe as pickle file

# %%
import pickle

pickle.dump(hugo_following_data, open( "/dbfs/FileStore/tmp/hugo_following_data.pkl", "wb" ) )

# %% [markdown]
# `.friends_ids()` function returns only user id of specific user, where user id and screen name can be used. This function perform faster than `.friends()` function because it only returns user id and it doesn't require cursors to navigate.
#
# `.get_user()` function returns information about specific user, where user id and screen name can be used.

# %% [markdown]
# ![alt](https://i.imgur.com/2rQYdpU.jpg)

# %% [markdown]
# Here we will extract user id of people who are followed by users that Hugo follows as illustrate in the schema above. Following function creates list of tuples with two elements. The first element is users followed by Hugo, and the second is dictionary of users followed by the first element. We use `.friends_ids()` function to get user id of the second users, then use `.get_user()` function to extract user information of the second users.

# %%
write_edgelist=[]
def second_friend(json):
  count=0
  for friend in json:
    friend_screen_name=friend['screen_name']
    id_list = api.friends_ids(screen_name=friend_screen_name)
    count+=1
    count_fol=0
    for second_id in id_list:
      second_user=api.get_user(id=second_id)
      second_screen_name=second_user.screen_name
      write_edgelist.append((friend_screen_name, second_user))
      count_fol+=1
      print("Friend {}".format(count), "following {} downloaded".format(count_fol))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
second_friend(hugo_following)

# %% [markdown]
# Since the second element is dictionary, we can extract any information related to the second element. This comes in handy when we do network analysis where we can analyze followee/follower relationship. In our case, the first element is the follower, the second element is followee and the extra information can be stored as node's metadata.

# %%
write_edgelist[0]

# %% [markdown]
# We can save this as pickle file.

# %%
import pickle

pickle.dump(write_edgelist, open( "/dbfs/FileStore/tmp/hugo_write_edgelist.pkl", "wb" ) )

# %% [markdown]
# ###3. Geo methods

# %% [markdown]
# `.geo_search()` helps us to extract location id.

# %%
places = api.geo_search(query="USA", granularity="country")
place_id = places[0].id
print('USA id is: ',place_id)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">USA id is:  96683cc9126741d1
# </div>

# %% [markdown]
# The USA's location ID is `96683cc9126741d1` which will allow us to extract tweets originated in the USA.

# %% [markdown]
# The following function extracts tweets and navigate to the next cursor.

# %%
import json
import time

geo_usa=[]
def process_or_store_geo(place):
    geo_usa.append(place)
    
def limit_handled(cursor):
  while True:
    try:
      yield cursor.next()
    except tweepy.RateLimitError:
      time.sleep(15 * 60)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# `.search()` function returns tweets that match a specified query. We can use place ID to collect tweets originated in the USA by including `'place:96683cc9126741d1'` to the search query. We can set up maximum number of tweets to extract.

# %%
searchquery='place:96683cc9126741d1'
max_tweets=10000
tweet_count=0

for tweet in limit_handled(tweepy.Cursor(api.search,q=searchquery).items(max_tweets)) :         
  if tweet.place is not None:
    process_or_store_geo(tweet._json)
    tweet_count += 1
    print("Downloaded {0} tweets".format(tweet_count))

# %% [markdown]
# Saving geo_usa as pickle file.

# %%
import pickle

pickle.dump(geo_usa, open( "/dbfs/FileStore/tmp/geo_usa.pkl", "wb" ))

# %%
# %sh ls -lh /dbfs/FileStore/tmp/*.pkl

# %% [markdown]
# Loading `geo_usa` pickle file as `geo_usa_location`.

# %%
import pickle

geo_usa_location = pickle.load(open( "/dbfs/FileStore/tmp/geo_usa.pkl", "rb" ))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
len(geo_usa_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">33</span><span class="ansired">]: </span>1424
# </div>

# %% [markdown]
# We can use the coodinates to map the origins of the tweets.

# %%
geo_usa[0]['place']['bounding_box']['coordinates']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">34</span><span class="ansired">]: </span>
# [[[-87.547173, 38.625181],
#   [-87.433471, 38.625181],
#   [-87.433471, 38.736046],
#   [-87.547173, 38.736046]]]
# </div>

# %% [markdown]
# ##2.3. Extracting old tweets

# %% [markdown]
# We can use `.search()` to extract old tweets.

# %%
import json
import time

old_tweets=[]
def process_or_store(tweet):
    old_tweets.append(json.dumps(tweet))

# %% [markdown]
# For example, here we extract tweets with `google` word in the text and written in English. We can also specify whether to include entities which are hashtags, user mentions, links, stock tickers (symbols), Twitter polls, and attached media. We can set up maximum number of tweets to extract, otherwise this will never stop.

# %%
tweet_count=0
max_count=10000
for tweet in tweepy.Cursor(api.search, 
                           q="google", 
                           result_type="recent", 
                           include_entities=True, 
                           lang="en"
                          ).items(max_count):
    tweet_count+=1
    process_or_store(tweet._json)
    print("Downloaded {0} tweets".format(tweet_count))

# %% [markdown]
# We can save it as pickle file.

# %%
import pickle

pickle.dump(old_tweets, open( "/dbfs/FileStore/tmp/google_tweets.pkl", "wb" ) )

# %%
# %sh ls -lh /dbfs/FileStore/tmp/*.pkl

# %%
import pickle
google_tweets = pickle.load(open( "/dbfs/FileStore/tmp/google_tweets.pkl", "rb" ) )

# %%
google_tweets[0]

# %% [markdown]
# The End
