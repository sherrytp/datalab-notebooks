# %% [markdown]
# # Parquet - `pyarrow`

# %% [markdown]
# - https://arrow.apache.org/docs/python/parquet.html

# %%
import pyarrow.parquet as pq
import pyarrow as pa
import numpy as np
import pandas as pd

df = pd.DataFrame({'one': [-1, np.nan, 2.5],
                   'two': ['foo', 'bar', 'baz'],
                   'three': [True, False, True]})

table = pa.Table.from_pandas(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>
#    one  three  two
# 0 -1.0   True  foo
# 1  NaN  False  bar
# 2  2.5   True  baz
# </div>

# %%
table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>
# pyarrow.Table
# one: double
# three: bool
# two: string
# __index_level_0__: int64
# metadata
# --------
# {b&apos;pandas&apos;: b&apos;{&quot;pandas_version&quot;: &quot;0.19.2&quot;, &quot;index_columns&quot;: [&quot;__index_level_0_&apos;
#             b&apos;_&quot;], &quot;column_indexes&quot;: [{&quot;field_name&quot;: null, &quot;pandas_type&quot;: &quot;uni&apos;
#             b&apos;code&quot;, &quot;metadata&quot;: {&quot;encoding&quot;: &quot;UTF-8&quot;}, &quot;name&quot;: null, &quot;numpy_t&apos;
# ...

# %%
import pyarrow.parquet as pq

pq.write_table(table, '/dbfs/FileStore/tmp/example.parquet')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ArrowIOError</span>                              Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2866233958143117&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">      1</span> <span class="ansigreen">import</span> pyarrow<span class="ansiyellow">.</span>parquet <span class="ansigreen">as</span> pq<span class="ansiyellow"></span>
# <span class="ansigreen">      2</span> <span class="ansiyellow"></span>
# ...

# %%
# %sh ls /dbfs/FileStore/tmp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ls: cannot access &apos;/dbfs/FileStore/tmp&apos;: No such file or directory
# </div>

# %%
del table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
table
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">NameError</span>                                 Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2866233958143120&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>table<span class="ansiyellow"></span>
#
# <span class="ansired">NameError</span>: name &apos;table&apos; is not defined</div>

# %%
pq.read_table('/dbfs/FileStore/tmp/example.parquet').to_pandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">ArrowIOError</span>                              Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2866233958143121&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# ...

# %%
# %fs ls /FileStore/tmp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">	at com.databricks.backend.daemon.data.client.DbfsClient.send0(DbfsClient.scala:92)
# 	at com.databricks.backend.daemon.data.client.DbfsClient.sendIdempotent(DbfsClient.scala:54)
# 	at com.databricks.backend.daemon.data.client.DatabricksFileSystemV1.listStatus(DatabricksFileSystemV1.scala:180)
# 	at com.databricks.backend.daemon.data.client.DatabricksFileSystem.listStatus(DatabricksFileSystem.scala:143)
# 	at com.databricks.backend.daemon.dbutils.FSUtils$$anonfun$ls$1.apply(DBUtilsCore.scala:83)
# 	at com.databricks.backend.daemon.dbutils.FSUtils$$anonfun$ls$1.apply(DBUtilsCore.scala:82)
# ...

# %%
# %sh ls /dbfs/FileStore/tmp
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">ls: cannot access &apos;/dbfs/FileStore/tmp&apos;: No such file or directory
# </div>

# %%
display(spark.read.parquet('/FileStore/tmp/example.parquet'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansigreen">&lt;command-2866233958143124&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# ...

# %%
spark.read.parquet('/FileStore/tmp/example.parquet').collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>
# [Row(one=-1.0, three=True, two=bytearray(b&apos;foo&apos;), __index_level_0__=0),
#  Row(one=None, three=False, two=bytearray(b&apos;bar&apos;), __index_level_0__=1),
#  Row(one=2.5, three=True, two=bytearray(b&apos;baz&apos;), __index_level_0__=2)]
# </div>
