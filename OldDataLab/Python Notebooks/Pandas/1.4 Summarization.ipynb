# %% [markdown]
# # `pandas` - `groupby`

# %% [markdown]
# __Contents__: an example using the `groupby` function

# %% [markdown]
# Related/useful documentation
# - http://pandas.pydata.org/pandas-docs/stable/index.html
# - https://pandas.pydata.org/pandas-docs/stable/dsintro.html
# - https://pandas.pydata.org/pandas-docs/stable/groupby.html

# %% [markdown]
# Load the libraries.

# %%
import pandas  as pd
import numpy   as np
(pd.__version__,
 np.__version__
)

# %% [markdown]
# Load the DataFrame from the `imports-85.csv` CSV file. Set the column names.

# %%
column_names = ['symboling', 'normalized-losses', 'make', 'fuel-type',
                'aspiration', 'num-of-doors', 'body-style', 'drive-wheels',
                'engine-location', 'wheel-base', 'length', 'width',
                'height', 'curb-weight', 'engine-type', 'num-of-cylinders',
                'engine-size', 'fuel-system', 'bore', 'stroke',
                'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
                'highway-mpg', 'price']
import_df = pd.read_csv('/dbfs/mnt/datalab-datasets/file-samples/imports-85.csv',
                        names=[string.replace('-','_') for string in column_names],
                        na_values=['?']
                       )

# %%
import_df.info()

# %%
import_df.groupby('make')[['make']].size()

# %%
import_df[['make','city_mpg','highway_mpg']].groupby('make').mean()

# %%
import_df.body_style.unique()

# %%
import_df[['make','body_style','city_mpg']].groupby(['make','body_style'])\
                                           .mean()\
                                           .sort_values(by='city_mpg',ascending=False)

# %%
import_df[['make','body_style','city_mpg','highway_mpg']]\
    .groupby(['make','body_style'])\
    .aggregate(np.mean)

# %%
import_df[['make','body_style','city_mpg','highway_mpg']]\
       .groupby(['make','body_style'])\
       .size()

# %%
import_df[['make','city_mpg','highway_mpg']]\
  .groupby(['make'])\
  .describe()

# %%
import_df[['make','city_mpg','highway_mpg']]\
  .groupby(['make'])\
  .agg({'city_mpg':np.mean,
        'highway_mpg':np.median})

# %% [markdown]
# __The End__
