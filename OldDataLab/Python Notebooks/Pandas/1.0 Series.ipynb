# %% [markdown]
# # `pandas` - Series

# %% [markdown]
# __Contents__:
# 1. Series
# 1. Numeric Series
# 1. Character Series
# 1. Time Series

# %% [markdown]
# Related/useful documentation:
# - http://pandas.pydata.org/pandas-docs/stable/index.html
# - https://pandas.pydata.org/pandas-docs/stable/dsintro.html

# %% [markdown]
# Load libraries.

# %%
import pandas  as pd
import numpy   as np
(pd.__version__,
 np.__version__
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>(&apos;0.18.1&apos;, &apos;1.11.1&apos;)
# </div>

# %% [markdown]
# __pandas objects__: There are two types of objects in pandas:
# - __Series__, which are 1-dimensional and contain only one type of value (i.e. `float64`, `int64`, `bool`, `object`)
# - __Dataframes__, which are 2-dimensional tables
#
# The columns of a DataFrame can be retrieved as a Series (or as a DataFrame with a single column.)
#
# Below I'll describe the three types of Series. Each has a different type of index. These are:
# - __Numeric Series__, where rows are labeled by numbers, which is the default
# - __Character Series__, where the rows are labeled by strings
# - __Time Series__, where the rows are labeled by `datetime` values
#
# The __index__ of a Series is a corresponding sequence of values used to refer to individual elements of or sets of elements of the Series.
#
# The indexing (retrieval of elements) is slightly different for each type of Series.

# %% [markdown]
# ## Series
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html

# %% [markdown]
# A __Series__ is a sequence of values and a corresponding sequence of names (an index) for these values.
#
# The sequence of values of a Series (of any of these types) can be returned as a 1-dimensional numpy array using the `values` method.

# %% [markdown]
# Series can be created with the `pandas.Series` function.

# %%
my_series = pd.Series(range(0,50,10))
my_series
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>
# 0     0
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64
# </div>

# %% [markdown]
# Every Series stores one type of object.

# %%
my_series.dtype
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>dtype(&apos;int64&apos;)
# </div>

# %% [markdown]
# Every Series has a length.

# %%
my_series.size
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>5
# </div>

# %%
my_series.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>(5,)
# </div>

# %%
len(my_series)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>5
# </div>

# %% [markdown]
# The counts of the distinct values of a Series are displayed by the `value_counts` method.

# %%
my_series.value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>
# 30    1
# 40    1
# 20    1
# 10    1
# 0     1
# dtype: int64
# </div>

# %% [markdown]
# The values of a Series can be converted into a 1-dimensional numpy array.

# %%
print(type(my_series.values))
my_series.values
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &apos;numpy.ndarray&apos;&gt;
# <span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>array([ 0, 10, 20, 30, 40])
# </div>

# %% [markdown]
# There are two ways to aggregate the values of a series.
# 1. Through methods of the Series object
# 1. Through numpy functions
#
# A couple of each are displayed below. More can be found in the documentation.

# %%
my_series.mean()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>20.0
# </div>

# %%
my_series.median()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>20.0
# </div>

# %%
my_series.sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>100
# </div>

# %%
np.square(my_series)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>
# 0       0
# 1     100
# 2     400
# 3     900
# 4    1600
# dtype: int64
# </div>

# %%
np.add(1000,my_series)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>
# 0    1000
# 1    1010
# 2    1020
# 3    1030
# 4    1040
# dtype: int64
# </div>

# %% [markdown]
# ## Numeric Indexed Series

# %% [markdown]
# - https://docs.scipy.org/doc/numpy/reference/routines.random.html

# %%
num_series = pd.Series(np.random.randint(100,110,11))
type(num_series)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>pandas.core.series.Series
# </div>

# %%
num_series
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>
# 0     106
# 1     108
# 2     102
# 3     107
# 4     107
# 5     100
# 6     105
# 7     107
# 8     109
# 9     109
# 10    106
# dtype: int64
# </div>

# %%
num_series.loc[num_series > 107]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>
# 1    108
# 8    109
# 9    109
# dtype: int64
# </div>

# %%
num_series.iloc[[0,2,4]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>
# 0    106
# 2    102
# 4    107
# dtype: int64
# </div>

# %%
num_series.iloc[:3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>
# 0    106
# 1    108
# 2    102
# dtype: int64
# </div>

# %%
my_series.loc[:3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>
# 0     0
# 1    10
# 2    20
# 3    30
# dtype: int64
# </div>

# %% [markdown]
# ### Character Indexed Series

# %%
my_series_chr_ndx = pd.Series(np.random.randint(100,110,12), 
                      index=['jan','feb','mar','apr','may','jun',
                             'jul','aug','sep','oct','nov','dec'])
my_series_chr_ndx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">20</span><span class="ansired">]: </span>
# jan    102
# feb    109
# mar    108
# apr    100
# may    108
# jun    109
# jul    106
# aug    107
# sep    108
# oct    102
# nov    103
# dec    102
# dtype: int64
# </div>

# %%
my_series_chr_ndx['jan']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">21</span><span class="ansired">]: </span>102
# </div>

# %%
my_series_chr_ndx['jan':'apr']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>
# jan    102
# feb    109
# mar    108
# apr    100
# dtype: int64
# </div>

# %%
my_series_chr_ndx.loc['jan':'apr']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">23</span><span class="ansired">]: </span>
# jan    102
# feb    109
# mar    108
# apr    100
# dtype: int64
# </div>

# %%
my_series_chr_ndx.iloc[0:3]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>
# jan    102
# feb    109
# mar    108
# dtype: int64
# </div>

# %%
my_series_chr_ndx[['jan','dec']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">25</span><span class="ansired">]: </span>
# jan    102
# dec    102
# dtype: int64
# </div>

# %% [markdown]
# ### Time Indexed Series
# - http://pandas.pydata.org/pandas-docs/stable/timeseries.html

# %% [markdown]
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.to_datetime.html

# %%
start_datetime = pd.to_datetime('201802031100', format='%Y%m%d%H%M')
start_datetime
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">26</span><span class="ansired">]: </span>Timestamp(&apos;2018-02-03 11:00:00&apos;)
# </div>

# %%
pd.date_range(start_datetime, periods=72, freq='H')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">27</span><span class="ansired">]: </span>
# DatetimeIndex([&apos;2018-02-03 11:00:00&apos;, &apos;2018-02-03 12:00:00&apos;,
#                &apos;2018-02-03 13:00:00&apos;, &apos;2018-02-03 14:00:00&apos;,
#                &apos;2018-02-03 15:00:00&apos;, &apos;2018-02-03 16:00:00&apos;,
#                &apos;2018-02-03 17:00:00&apos;, &apos;2018-02-03 18:00:00&apos;,
#                &apos;2018-02-03 19:00:00&apos;, &apos;2018-02-03 20:00:00&apos;,
#                &apos;2018-02-03 21:00:00&apos;, &apos;2018-02-03 22:00:00&apos;,
