# %% [markdown]
# # NetworkX: Degree, betweenness and closeness

# %%
# %sh /databricks/python3/bin/pip3 install networkx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Collecting networkx
#   Downloading networkx-2.1.zip (1.6MB)
# Collecting decorator&gt;=4.1.0 (from networkx)
#   Downloading decorator-4.2.1-py2.py3-none-any.whl
# Building wheels for collected packages: networkx
#   Running setup.py bdist_wheel for networkx: started
#   Running setup.py bdist_wheel for networkx: finished with status &apos;done&apos;
#   Stored in directory: /root/.cache/pip/wheels/a0/33/4e/7c9228ea77f8090e895d8d2b76f3b5a76997a5b3edeb4e2c6f
# Successfully built networkx
# Installing collected packages: decorator, networkx
#   Found existing installation: decorator 4.0.10
#     Uninstalling decorator-4.0.10:
#       Successfully uninstalled decorator-4.0.10
# Successfully installed decorator-4.2.1 networkx-2.1
# </div>

# %%
import networkx          as nx
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import itertools
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## 1. Degree and degree centrality

# %% [markdown]
# __Degree__ is used to identify an important node in the network and defined as a number of edges attached to a node. In-degree refers to number of edges pointing into the node and out-degree refers to number of edges going out from the node. In and out degree work for directed graphs.

# %%
G=nx.DiGraph()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Let's add egdes and nodes to graph `G`.

# %%
edges=[("Jane","Joe"), ("Joe","Martin"), ("Martin","Harris"), ("Harris","Calvin"), 
       ("Jane","Rob"), ("Harris","Rob"),("Rob","Martin"),("Jane","Martin"),("Rose","Martin")]

G.add_edges_from(edges)
BLUE = "#05006d"
nx.draw(G, node_color=BLUE, 
           with_labels=True, 
           node_size=4200, 
           font_size=18, 
           font_weight='bold', 
           font_color='white', 
           arrowsize=40)
display(plt.show())
plt.clf()

# %% [markdown]
# Here we can observe that Martin has highest connection with 6 other people or neighbors. 4 out of 5 connections are directed towards Martin and 1 is directed out. To define degree of a node, we use `nx.degree()` function. In and out degrees are defined using `nx.in_degree()` and `nx.out_degree()` functions respectively which are only used in directed graphs. When ties are associated to some positive aspects such as friendship or collaboration, indegree is often interpreted as a form of popularity, and outdegree as gregariousness.

# %% [markdown]
# $$ Degree{\ \}centrality=\frac{Number{\ \}of{\ \}neighboring{\ \}nodes}{All{\ \}possible{\ \}number{\ \}of{\ \}neighboring{\ \}nodes} $$

# %%
nx.degree(G)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>DiDegreeView({&apos;Rose&apos;: 1, &apos;Jane&apos;: 3, &apos;Joe&apos;: 2, &apos;Martin&apos;: 5, &apos;Harris&apos;: 3, &apos;Rob&apos;: 3, &apos;Calvin&apos;: 1})
# </div>

# %% [markdown]
# __Degree centrality__ is normalized degree value that is calculated by dividing number of degrees to possible number of degrees that each node can have.
# Degree centrality measures how many direct, ‘one hop’ connections each node has to other nodes within the network.
# We use degree centrality for finding very connected individuals, popular individuals, individuals who are likely to hold most information or individuals who can quickly connect with the wider network.

# %% [markdown]
# `nx.degree_centrality` function is used.

# %%
dc=nx.degree_centrality(G)

sorted(dc.items(), 
       key=lambda item: item[1], 
       reverse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>
# [(&apos;Martin&apos;, 0.8333333333333333),
#  (&apos;Jane&apos;, 0.5),
#  (&apos;Harris&apos;, 0.5),
#  (&apos;Rob&apos;, 0.5),
#  (&apos;Joe&apos;, 0.3333333333333333),
#  (&apos;Rose&apos;, 0.16666666666666666),
#  (&apos;Calvin&apos;, 0.16666666666666666)]
# </div>

# %% [markdown]
# From degree centrality, we conclude that Martin is the most important node in this network and can be characterized as popular and well connected.

# %% [markdown]
# ## 2. Betweenness centrality

# %% [markdown]
# __Betweenness centrality__
#
# Betweenness measures the number of times a node lies on the shortest path between other nodes. It's used for finding the individuals who influence the flow around a system. Betweenness centrality is normalized betweenness value that is calculated by diving number of shortest path through node by all possible number of shortest paths.

# %% [markdown]
# __Shortest path__
#
# A path between two vertices (or nodes) in a graph such that the sum of the weights of its constituent edges is minimized.

# %% [markdown]
# $$ Betweenness{\ \}centrality=\frac{Number{\ \}of{\ \}shortest{\ \}paths{\ \}through{\ \}node}{All{\ \}possible{\ \}number{\ \}of{\ \}shortest{\ \}paths} $$

# %% [markdown]
# `nx.betweenness_centrality()` returns normalized betweenness centrality. To calculate betweenness, set `nomalized` parameter to `False`.

# %%
betweenness=nx.betweenness_centrality(G, normalized=False)

sorted(betweenness.items(), key=lambda item: item[1], reverse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>
# [(&apos;Martin&apos;, 10.0),
#  (&apos;Harris&apos;, 8.0),
#  (&apos;Rob&apos;, 1.0),
#  (&apos;Rose&apos;, 0.0),
#  (&apos;Jane&apos;, 0.0),
#  (&apos;Joe&apos;, 0.0),
#  (&apos;Calvin&apos;, 0.0)]
# </div>

# %%
bc=nx.betweenness_centrality(G)

sorted(bc.items(), key=lambda item: item[1], reverse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">22</span><span class="ansired">]: </span>
# [(&apos;Martin&apos;, 0.3333333333333333),
#  (&apos;Harris&apos;, 0.26666666666666666),
#  (&apos;Rob&apos;, 0.03333333333333333),
#  (&apos;Rose&apos;, 0.0),
#  (&apos;Jane&apos;, 0.0),
#  (&apos;Joe&apos;, 0.0),
#  (&apos;Calvin&apos;, 0.0)]
# </div>

# %% [markdown]
# Here Martin and Harris have the highest betweenness centrality, meaning that these two nodes influence the information flow of the network.

# %% [markdown]
# ## 3. Closeness centrality

# %% [markdown]
# This measure scores each node based on their ‘closeness’ to all other nodes within the network. This measure calculates the shortest paths between all nodes, then assigns each node a score based on its sum of shortest paths. For finding the individuals who are best placed to influence the entire network most quickly. Closeness centrality can help find good ‘broadcasters’, but in a highly connected network you will often find all nodes have a similar score. What may be more useful is using Closeness to find influencers within a single cluster.
# Thus the more central a node is, the closer it is to all other nodes

# %%
cc=nx.closeness_centrality(G)

sorted(cc.items(), key=lambda item: item[1], reverse=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">20</span><span class="ansired">]: </span>
# [(&apos;Martin&apos;, 0.6944444444444445),
#  (&apos;Harris&apos;, 0.462962962962963),
#  (&apos;Rob&apos;, 0.4166666666666667),
#  (&apos;Calvin&apos;, 0.4),
#  (&apos;Joe&apos;, 0.16666666666666666),
#  (&apos;Rose&apos;, 0.0),
#  (&apos;Jane&apos;, 0.0)]
# </div>

# %% [markdown]
# Other centrality measures, refer to https://networkx.github.io/documentation/networkx-1.9/reference/algorithms.centrality.html

# %%
dcs=[]
bcs=[]
ccs=[]
for u, v in sorted(dc.items(), key=lambda item: item[0], reverse=False):
  dcs.append(v)
for u, v in sorted(bc.items(), key=lambda item: item[0], reverse=False):
  bcs.append(v)
for u,v in sorted(cc.items(), key=lambda item: item[0], reverse=False):
  ccs.append(v)
pd.DataFrame({"degree centrality": dcs, "betweenness centrality": bcs, "closeness centrality": ccs}, index=sorted(G.nodes, reverse=False))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">56</span><span class="ansired">]: </span>
#         betweenness centrality  closeness centrality  degree centrality
# Calvin                0.000000              0.400000           0.166667
# Harris                0.266667              0.462963           0.500000
# Jane                  0.000000              0.000000           0.500000
# Joe                   0.000000              0.166667           0.333333
# Martin                0.333333              0.694444           0.833333
# Rob                   0.033333              0.416667           0.500000
# Rose                  0.000000              0.000000           0.166667
# </div>

# %% [markdown]
# ##4. Degree, betweenness and closeness centrality of weighted graph

# %%
weighted_edges=[("Harris", "Calvin", 5), ("Joe", "Martin", 4), ("Jane", "Rob", 2),("Harris", "Rob", 3), 
                ("Rob", "Martin", 1), ("Jane", "Martin", 8), ("Martin", "Harris", 4), ("Jane", "Joe", 2),("Rose","Martin", 6)]
G.add_weighted_edges_from(weighted_edges)
G.edges.data("weight")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">103</span><span class="ansired">]: </span>OutEdgeDataView([(&apos;Rose&apos;, &apos;Martin&apos;, 6), (&apos;Jane&apos;, &apos;Rob&apos;, 2), (&apos;Jane&apos;, &apos;Joe&apos;, 2), (&apos;Jane&apos;, &apos;Martin&apos;, 8), (&apos;Joe&apos;, &apos;Martin&apos;, 4), (&apos;Martin&apos;, &apos;Harris&apos;, 4), (&apos;Rob&apos;, &apos;Martin&apos;, 1), (&apos;Harris&apos;, &apos;Rob&apos;, 3), (&apos;Harris&apos;, &apos;Calvin&apos;, 5)])
# </div>

# %%
BLUE = "#05006d"
weights = [G[u][v]['weight'] for u,v in edges]
nx.draw(G, node_color=BLUE, 
           with_labels=True, 
           node_size=4200, 
           font_size=18, 
           font_weight='bold', 
           font_color='white', 
           arrowsize=40,
           width=weights)
display(plt.show())
plt.clf()

# %%
[G.degree(),
G.degree(weight="weight")]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">123</span><span class="ansired">]: </span>
# [DiDegreeView({&apos;Rose&apos;: 1, &apos;Jane&apos;: 3, &apos;Joe&apos;: 2, &apos;Martin&apos;: 5, &apos;Harris&apos;: 3, &apos;Rob&apos;: 3, &apos;Calvin&apos;: 1}),
#  DiDegreeView({&apos;Rose&apos;: 6, &apos;Jane&apos;: 12, &apos;Joe&apos;: 6, &apos;Martin&apos;: 23, &apos;Harris&apos;: 12, &apos;Rob&apos;: 6, &apos;Calvin&apos;: 5})]
# </div>

# %%
pd.DataFrame([nx.betweenness_centrality(G),
nx.betweenness_centrality(G, weight="weight")], index=["Unweighted","Weighted"]).transpose()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">121</span><span class="ansired">]: </span>
#         Unweighted  Weighted
# Calvin    0.000000  0.000000
# Harris    0.266667  0.266667
# Jane      0.000000  0.000000
# Joe       0.000000  0.000000
# Martin    0.333333  0.333333
# Rob       0.033333  0.133333
# Rose      0.000000  0.000000
# </div>

# %%
pd.DataFrame([nx.closeness_centrality(G),
nx.closeness_centrality(G, distance="weight")], index=["Unweighted","Weighted"]).transpose()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">126</span><span class="ansired">]: </span>
#         Unweighted  Weighted
# Calvin    0.400000  0.000000
# Harris    0.462963  0.125000
# Jane      0.000000  0.160256
# Joe       0.166667  0.074074
# Martin    0.694444  0.075000
# Rob       0.416667  0.093750
# Rose      0.000000  0.060606
# </div>

# %% [markdown]
# The End
