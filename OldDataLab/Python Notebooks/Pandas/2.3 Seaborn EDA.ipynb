# %% [markdown]
# # `pandas` - Clean DataFrame

# %% [markdown]
# Goal of this notebook is to create a useful dataset with appropriate values and variables.
#
# __[EDIT]__
#
# Deal with missing values
#
# Create features (aka variables or columns)
# - changing units
# - splitting/joining strings

# %% [markdown]
# ## Introduction
#
# There are three basic steps to cleaning data:
# 1. Dealing with missing values
# 1. Manipulating strings
# 1. Manipulating datetimes
#
# Each is described in a separate section below.
#
# First though libraries are loaded and define the `read_dataframe` function.

# %% [markdown]
# Load the libraries.

# %%
import pandas  as pd
import numpy   as np
(pd.__version__,
 np.__version__
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">1</span><span class="ansired">]: </span>(&apos;0.18.1&apos;, &apos;1.11.1&apos;)
# </div>

# %% [markdown]
# Create a dataframe from the `imports-85.csv` CSV file. Set the column names.

# %%
def read_college_scorecard(file_path='/dbfs/mnt/datalab-datasets/college-scorecard/MERGED2013_PP.csv',
                           n_rows=None):
  return pd.read_csv(file_path,
                     nrows=n_rows,
                     na_values=['PrivacySuppressed']
                     )
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
read_college_scorecard().info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2833: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code):
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# RangeIndex: 7804 entries, 0 to 7803
# Columns: 1729 entries, ﻿UNITID to C200_4_POOLED_SUPP
# dtypes: float64(1710), int64(12), object(7)
# memory usage: 102.9+ MB
# </div>

# %% [markdown]
# ## Missing Values

# %% [markdown]
# Recall that the `isnull` method takes a Series/DataFrame as input and indicates whether the elements of the input are `NaN`.
#
# The output has the same shape as the input.

# %%
(read_college_scorecard().shape,
 read_college_scorecard().isnull().shape
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>((7804, 1729), (7804, 1729))
# </div>

# %% [markdown]
# The first five values of the `C150_L4_POOLED_SUPP` variable are missing.

# %%
read_college_scorecard().isnull().head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">5</span><span class="ansired">]: </span>
#   ﻿UNITID  OPEID opeid6 INSTNM   CITY STABBR    ZIP AccredAgency INSTURL  \
# 0   False  False  False  False  False  False  False        False   False
# 1   False  False  False  False  False  False  False        False   False
# 2   False  False  False  False  False  False  False        False   False
# 3   False  False  False  False  False  False  False        False   False
# 4   False  False  False  False  False  False  False        False   False
#
#   NPCURL        ...         PELL_RPY_3YR_RT_SUPP NOPELL_RPY_3YR_RT_SUPP  \
# 0  False        ...                        False                  False
# 1  False        ...                        False                  False
# 2  False        ...                        False                  False
# 3  False        ...                        False                  False
# 4  False        ...                        False                  False
#
#   FEMALE_RPY_3YR_RT_SUPP MALE_RPY_3YR_RT_SUPP FIRSTGEN_RPY_3YR_RT_SUPP  \
# 0                  False                False                    False
# 1                  False                False                    False
# 2                  False                False                    False
# 3                  False                False                    False
# 4                  False                False                    False
#
#   NOTFIRSTGEN_RPY_3YR_RT_SUPP C150_L4_POOLED_SUPP C150_4_POOLED_SUPP  \
# 0                       False                True              False
# 1                       False                True              False
# 2                       False                True               True
# 3                       False                True              False
# 4                       False                True              False
#
#   C200_L4_POOLED_SUPP C200_4_POOLED_SUPP
# 0                True              False
# 1                True              False
# 2                True               True
# 3                True              False
# 4                True              False
#
# [5 rows x 1729 columns]
# </div>

# %% [markdown]
# This can be used to list the variables/columns with missing values and indicate the number of missing values for each.

# %%
read_college_scorecard().isnull().sum(axis=0).sort_values(ascending=False)[lambda x: x > 0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">6</span><span class="ansired">]: </span>
# DEP_ENRL_ORIG_YR4_RT             7804
# PELL_DEATH_YR4_RT                7804
# MALE_WDRAW_2YR_TRANS_YR4_RT      7804
# MALE_ENRL_ORIG_YR4_RT            7804
# MALE_ENRL_4YR_TRANS_YR4_RT       7804
# MALE_ENRL_2YR_TRANS_YR4_RT       7804
# MALE_UNKN_ORIG_YR4_RT            7804
# MALE_UNKN_4YR_TRANS_YR4_RT       7804
# MALE_UNKN_2YR_TRANS_YR4_RT       7804
# PELL_COMP_ORIG_YR4_RT            7804
# PELL_UNKN_ORIG_YR4_RT            7804
# PELL_COMP_4YR_TRANS_YR4_RT       7804
# PELL_COMP_2YR_TRANS_YR4_RT       7804
# PELL_WDRAW_ORIG_YR4_RT           7804
# PELL_WDRAW_4YR_TRANS_YR4_RT      7804
# PELL_WDRAW_2YR_TRANS_YR4_RT      7804
# PELL_ENRL_ORIG_YR4_RT            7804
# PELL_ENRL_4YR_TRANS_YR4_RT       7804
# MALE_WDRAW_4YR_TRANS_YR4_RT      7804
# MALE_WDRAW_ORIG_YR4_RT           7804
# MALE_COMP_2YR_TRANS_YR4_RT       7804
# MALE_COMP_4YR_TRANS_YR4_RT       7804
# FEMALE_DEATH_YR4_RT              7804
# FEMALE_COMP_ORIG_YR4_RT          7804
# FEMALE_COMP_4YR_TRANS_YR4_RT     7804
# FEMALE_COMP_2YR_TRANS_YR4_RT     7804
# FEMALE_WDRAW_ORIG_YR4_RT         7804
# FEMALE_WDRAW_4YR_TRANS_YR4_RT    7804
# FEMALE_WDRAW_2YR_TRANS_YR4_RT    7804
# FEMALE_ENRL_ORIG_YR4_RT          7804
#                                  ...
# CIP39ASSOC                        421
# CIP39CERT2                        421
# CIP39CERT1                        421
# CIP27CERT1                        421
# CIP38CERT4                        421
# CIP38ASSOC                        421
# CIP38CERT2                        421
# CIP38CERT1                        421
# CIP31BACHL                        421
# CIP31CERT4                        421
# CIP31ASSOC                        421
# CIP38BACHL                        421
# CIP31CERT1                        421
# CIP29ASSOC                        421
# CIP30BACHL                        421
# CIP27CERT2                        421
# CIP27ASSOC                        421
# CIP27BACHL                        421
# CIP29CERT1                        421
# CIP29CERT2                        421
# CIP27CERT4                        421
# CIP29CERT4                        421
# CIP29BACHL                        421
# CIP30CERT1                        421
# CIP30CERT2                        421
# CIP30ASSOC                        421
# CIP30CERT4                        421
# APPL_SCH_N                        324
# INSTURL                            85
# CDR3                               62
# dtype: int64
# </div>

# %% [markdown]
# This list has many elements so a visual inspection isn't very useful.
#
# The `describe` method summarizes the number of missing values of the variables.

# %%
read_college_scorecard().isnull().sum(axis=0).sort_values(ascending=False)[lambda x: x > 0].describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">7</span><span class="ansired">]: </span>
# count    1713.000000
# mean     6044.914186
# std      2861.623608
# min        62.000000
# 25%      4189.000000
# 50%      7804.000000
# 75%      7804.000000
# max      7804.000000
# dtype: float64
# </div>

# %% [markdown]
# Notice that over half of the variables contain no valid (non-missing) values.
#
# In the next sections:
# - Columns will be dropped that do not meet a certain threshold of valid values.
# - Columns will be dropped that do not meet a certain threshold of valid values.
# - The remaining missing values will be imputed (filled in.)

# %% [markdown]
# ### Drop Rows/Columns (`dropna` Method)
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.dropna.html

# %% [markdown]
# Notice the number of rows and columns in the dataframe.

# %%
read_college_scorecard()\
  .shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">8</span><span class="ansired">]: </span>(7804, 1729)
# </div>

# %% [markdown]
# Drop all columns with fewer than 90% (7024) valid values,

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">9</span><span class="ansired">]: </span>(7804, 281)
# </div>

# %% [markdown]
# List the columns that remain.

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .pipe(lambda df: list(df.columns))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">10</span><span class="ansired">]: </span>
# [&apos;\ufeffUNITID&apos;,
#  &apos;OPEID&apos;,
#  &apos;opeid6&apos;,
#  &apos;INSTNM&apos;,
#  &apos;CITY&apos;,
#  &apos;STABBR&apos;,
#  &apos;ZIP&apos;,
#  &apos;INSTURL&apos;,
#  &apos;NPCURL&apos;,
#  &apos;HCM2&apos;,
#  &apos;main&apos;,
#  &apos;NUMBRANCH&apos;,
#  &apos;PREDDEG&apos;,
#  &apos;HIGHDEG&apos;,
#  &apos;CONTROL&apos;,
#  &apos;st_fips&apos;,
#  &apos;region&apos;,
#  &apos;LOCALE&apos;,
#  &apos;HBCU&apos;,
#  &apos;PBI&apos;,
#  &apos;ANNHI&apos;,
#  &apos;TRIBAL&apos;,
#  &apos;AANAPII&apos;,
#  &apos;HSI&apos;,
#  &apos;NANTI&apos;,
#  &apos;MENONLY&apos;,
#  &apos;WOMENONLY&apos;,
#  &apos;PCIP01&apos;,
#  &apos;PCIP03&apos;,
#  &apos;PCIP04&apos;,
#  &apos;PCIP05&apos;,
#  &apos;PCIP09&apos;,
#  &apos;PCIP10&apos;,
#  &apos;PCIP11&apos;,
#  &apos;PCIP12&apos;,
#  &apos;PCIP13&apos;,
#  &apos;PCIP14&apos;,
#  &apos;PCIP15&apos;,
#  &apos;PCIP16&apos;,
#  &apos;PCIP19&apos;,
#  &apos;PCIP22&apos;,
#  &apos;PCIP23&apos;,
#  &apos;PCIP24&apos;,
#  &apos;PCIP25&apos;,
#  &apos;PCIP26&apos;,
#  &apos;PCIP27&apos;,
#  &apos;PCIP29&apos;,
#  &apos;PCIP30&apos;,
#  &apos;PCIP31&apos;,
#  &apos;PCIP38&apos;,
#  &apos;PCIP39&apos;,
#  &apos;PCIP40&apos;,
#  &apos;PCIP41&apos;,
#  &apos;PCIP42&apos;,
#  &apos;PCIP43&apos;,
#  &apos;PCIP44&apos;,
#  &apos;PCIP45&apos;,
#  &apos;PCIP46&apos;,
#  &apos;PCIP47&apos;,
#  &apos;PCIP48&apos;,
#  &apos;PCIP49&apos;,
#  &apos;PCIP50&apos;,
#  &apos;PCIP51&apos;,
#  &apos;PCIP52&apos;,
#  &apos;PCIP54&apos;,
#  &apos;CIP01CERT1&apos;,
#  &apos;CIP01CERT2&apos;,
#  &apos;CIP01ASSOC&apos;,
#  &apos;CIP01CERT4&apos;,
#  &apos;CIP01BACHL&apos;,
#  &apos;CIP03CERT1&apos;,
#  &apos;CIP03CERT2&apos;,
#  &apos;CIP03ASSOC&apos;,
#  &apos;CIP03CERT4&apos;,
#  &apos;CIP03BACHL&apos;,
#  &apos;CIP04CERT1&apos;,
#  &apos;CIP04CERT2&apos;,
#  &apos;CIP04ASSOC&apos;,
#  &apos;CIP04CERT4&apos;,
#  &apos;CIP04BACHL&apos;,
#  &apos;CIP05CERT1&apos;,
#  &apos;CIP05CERT2&apos;,
#  &apos;CIP05ASSOC&apos;,
#  &apos;CIP05CERT4&apos;,
#  &apos;CIP05BACHL&apos;,
#  &apos;CIP09CERT1&apos;,
#  &apos;CIP09CERT2&apos;,
#  &apos;CIP09ASSOC&apos;,
#  &apos;CIP09CERT4&apos;,
#  &apos;CIP09BACHL&apos;,
#  &apos;CIP10CERT1&apos;,
#  &apos;CIP10CERT2&apos;,
#  &apos;CIP10ASSOC&apos;,
#  &apos;CIP10CERT4&apos;,
#  &apos;CIP10BACHL&apos;,
#  &apos;CIP11CERT1&apos;,
#  &apos;CIP11CERT2&apos;,
#  &apos;CIP11ASSOC&apos;,
#  &apos;CIP11CERT4&apos;,
#  &apos;CIP11BACHL&apos;,
#  &apos;CIP12CERT1&apos;,
#  &apos;CIP12CERT2&apos;,
#  &apos;CIP12ASSOC&apos;,
#  &apos;CIP12CERT4&apos;,
#  &apos;CIP12BACHL&apos;,
#  &apos;CIP13CERT1&apos;,
#  &apos;CIP13CERT2&apos;,
#  &apos;CIP13ASSOC&apos;,
#  &apos;CIP13CERT4&apos;,
#  &apos;CIP13BACHL&apos;,
#  &apos;CIP14CERT1&apos;,
#  &apos;CIP14CERT2&apos;,
#  &apos;CIP14ASSOC&apos;,
#  &apos;CIP14CERT4&apos;,
#  &apos;CIP14BACHL&apos;,
#  &apos;CIP15CERT1&apos;,
#  &apos;CIP15CERT2&apos;,
#  &apos;CIP15ASSOC&apos;,
#  &apos;CIP15CERT4&apos;,
#  &apos;CIP15BACHL&apos;,
#  &apos;CIP16CERT1&apos;,
#  &apos;CIP16CERT2&apos;,
#  &apos;CIP16ASSOC&apos;,
#  &apos;CIP16CERT4&apos;,
#  &apos;CIP16BACHL&apos;,
#  &apos;CIP19CERT1&apos;,
#  &apos;CIP19CERT2&apos;,
#  &apos;CIP19ASSOC&apos;,
#  &apos;CIP19CERT4&apos;,
#  &apos;CIP19BACHL&apos;,
#  &apos;CIP22CERT1&apos;,
#  &apos;CIP22CERT2&apos;,
#  &apos;CIP22ASSOC&apos;,
#  &apos;CIP22CERT4&apos;,
#  &apos;CIP22BACHL&apos;,
#  &apos;CIP23CERT1&apos;,
#  &apos;CIP23CERT2&apos;,
#  &apos;CIP23ASSOC&apos;,
#  &apos;CIP23CERT4&apos;,
#  &apos;CIP23BACHL&apos;,
#  &apos;CIP24CERT1&apos;,
#  &apos;CIP24CERT2&apos;,
#  &apos;CIP24ASSOC&apos;,
#  &apos;CIP24CERT4&apos;,
#  &apos;CIP24BACHL&apos;,
#  &apos;CIP25CERT1&apos;,
#  &apos;CIP25CERT2&apos;,
#  &apos;CIP25ASSOC&apos;,
#  &apos;CIP25CERT4&apos;,
#  &apos;CIP25BACHL&apos;,
#  &apos;CIP26CERT1&apos;,
#  &apos;CIP26CERT2&apos;,
#  &apos;CIP26ASSOC&apos;,
#  &apos;CIP26CERT4&apos;,
#  &apos;CIP26BACHL&apos;,
#  &apos;CIP27CERT1&apos;,
#  &apos;CIP27CERT2&apos;,
#  &apos;CIP27ASSOC&apos;,
#  &apos;CIP27CERT4&apos;,
#  &apos;CIP27BACHL&apos;,
#  &apos;CIP29CERT1&apos;,
#  &apos;CIP29CERT2&apos;,
#  &apos;CIP29ASSOC&apos;,
#  &apos;CIP29CERT4&apos;,
#  &apos;CIP29BACHL&apos;,
#  &apos;CIP30CERT1&apos;,
#  &apos;CIP30CERT2&apos;,
#  &apos;CIP30ASSOC&apos;,
#  &apos;CIP30CERT4&apos;,
#  &apos;CIP30BACHL&apos;,
#  &apos;CIP31CERT1&apos;,
#  &apos;CIP31CERT2&apos;,
#  &apos;CIP31ASSOC&apos;,
#  &apos;CIP31CERT4&apos;,
#  &apos;CIP31BACHL&apos;,
#  &apos;CIP38CERT1&apos;,
#  &apos;CIP38CERT2&apos;,
#  &apos;CIP38ASSOC&apos;,
#  &apos;CIP38CERT4&apos;,
#  &apos;CIP38BACHL&apos;,
#  &apos;CIP39CERT1&apos;,
#  &apos;CIP39CERT2&apos;,
#  &apos;CIP39ASSOC&apos;,
#  &apos;CIP39CERT4&apos;,
#  &apos;CIP39BACHL&apos;,
#  &apos;CIP40CERT1&apos;,
#  &apos;CIP40CERT2&apos;,
#  &apos;CIP40ASSOC&apos;,
#  &apos;CIP40CERT4&apos;,
#  &apos;CIP40BACHL&apos;,
#  &apos;CIP41CERT1&apos;,
#  &apos;CIP41CERT2&apos;,
#  &apos;CIP41ASSOC&apos;,
#  &apos;CIP41CERT4&apos;,
#  &apos;CIP41BACHL&apos;,
#  &apos;CIP42CERT1&apos;,
#  &apos;CIP42CERT2&apos;,
#  &apos;CIP42ASSOC&apos;,
#  &apos;CIP42CERT4&apos;,
#  &apos;CIP42BACHL&apos;,
#  &apos;CIP43CERT1&apos;,
#  &apos;CIP43CERT2&apos;,
#  &apos;CIP43ASSOC&apos;,
#  &apos;CIP43CERT4&apos;,
#  &apos;CIP43BACHL&apos;,
#  &apos;CIP44CERT1&apos;,
#  &apos;CIP44CERT2&apos;,
#  &apos;CIP44ASSOC&apos;,
#  &apos;CIP44CERT4&apos;,
#  &apos;CIP44BACHL&apos;,
#  &apos;CIP45CERT1&apos;,
#  &apos;CIP45CERT2&apos;,
#  &apos;CIP45ASSOC&apos;,
#  &apos;CIP45CERT4&apos;,
#  &apos;CIP45BACHL&apos;,
#  &apos;CIP46CERT1&apos;,
#  &apos;CIP46CERT2&apos;,
#  &apos;CIP46ASSOC&apos;,
#  &apos;CIP46CERT4&apos;,
#  &apos;CIP46BACHL&apos;,
#  &apos;CIP47CERT1&apos;,
#  &apos;CIP47CERT2&apos;,
#  &apos;CIP47ASSOC&apos;,
#  &apos;CIP47CERT4&apos;,
#  &apos;CIP47BACHL&apos;,
#  &apos;CIP48CERT1&apos;,
#  &apos;CIP48CERT2&apos;,
#  &apos;CIP48ASSOC&apos;,
#  &apos;CIP48CERT4&apos;,
#  &apos;CIP48BACHL&apos;,
#  &apos;CIP49CERT1&apos;,
#  &apos;CIP49CERT2&apos;,
#  &apos;CIP49ASSOC&apos;,
#  &apos;CIP49CERT4&apos;,
#  &apos;CIP49BACHL&apos;,
#  &apos;CIP50CERT1&apos;,
#  &apos;CIP50CERT2&apos;,
#  &apos;CIP50ASSOC&apos;,
#  &apos;CIP50CERT4&apos;,
#  &apos;CIP50BACHL&apos;,
#  &apos;CIP51CERT1&apos;,
#  &apos;CIP51CERT2&apos;,
#  &apos;CIP51ASSOC&apos;,
#  &apos;CIP51CERT4&apos;,
#  &apos;CIP51BACHL&apos;,
#  &apos;CIP52CERT1&apos;,
#  &apos;CIP52CERT2&apos;,
#  &apos;CIP52ASSOC&apos;,
#  &apos;CIP52CERT4&apos;,
#  &apos;CIP52BACHL&apos;,
#  &apos;CIP54CERT1&apos;,
#  &apos;CIP54CERT2&apos;,
#  &apos;CIP54ASSOC&apos;,
#  &apos;CIP54CERT4&apos;,
#  &apos;CIP54BACHL&apos;,
#  &apos;DISTANCEONLY&apos;,
#  &apos;UGDS&apos;,
#  &apos;UGDS_WHITE&apos;,
#  &apos;UGDS_BLACK&apos;,
#  &apos;UGDS_HISP&apos;,
#  &apos;UGDS_ASIAN&apos;,
#  &apos;UGDS_AIAN&apos;,
#  &apos;UGDS_NHPI&apos;,
#  &apos;UGDS_2MOR&apos;,
#  &apos;UGDS_NRA&apos;,
#  &apos;UGDS_UNKN&apos;,
#  &apos;PPTUG_EF&apos;,
#  &apos;CURROPER&apos;,
#  &apos;TUITFTE&apos;,
#  &apos;INEXPFTE&apos;,
#  &apos;PCTPELL&apos;,
#  &apos;PCTFLOAN&apos;,
#  &apos;UG25abv&apos;,
#  &apos;CDR3&apos;,
#  &apos;DEP_STAT_PCT_IND&apos;,
#  &apos;APPL_SCH_PCT_GE2&apos;,
#  &apos;DEP_INC_AVG&apos;,
#  &apos;IND_INC_AVG&apos;,
#  &apos;DEP_INC_N&apos;,
#  &apos;IND_INC_N&apos;,
#  &apos;APPL_SCH_N&apos;]
# </div>

# %% [markdown]
# Drop all rows with fewer than 90% (254) valid values.

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>(7086, 281)
# </div>

# %% [markdown]
# Notice that there are now `7086` rows after dropping rows with fewer than `254` valid values. (We had `7804` rows.)

# %% [markdown]
# List the number of remaining missing values for all variables. In all cases we should have fewer than 10% (780) missing values.

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .isnull()\
  .sum(axis=0)\
  .sort_values(ascending=False)[lambda x: x > 0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>
# IND_INC_AVG         444
# DEP_INC_AVG         433
# IND_INC_N           426
# DEP_INC_N           426
# DEP_STAT_PCT_IND    355
# APPL_SCH_PCT_GE2    249
# APPL_SCH_N           73
# NPCURL               64
# UG25abv              61
# CDR3                 59
# INSTURL              57
# PCTPELL              23
# PCTFLOAN             23
# TUITFTE              21
# INEXPFTE             21
# PPTUG_EF             14
# UGDS_HISP             3
# UGDS                  3
# UGDS_WHITE            3
# UGDS_BLACK            3
# UGDS_ASIAN            3
# UGDS_UNKN             3
# UGDS_NRA              3
# UGDS_AIAN             3
# LOCALE                3
# UGDS_2MOR             3
# UGDS_NHPI             3
# dtype: int64
# </div>

# %% [markdown]
# ### Replace Missing Values (`fillna` Method)

# %% [markdown]
# - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.fillna.html
#
# Filling forward/backward, which is often used to fill missing values in time series, is not covered here.

# %% [markdown]
# Which variable should not be imputed? The default imputation method is the median of the valid values. Consider whether there are variables  that:
# 1. require a different imputation method
# 1. should never be missing or imputed
#
# The second case implies that rows with missing values for that variable should be dropped.

# %% [markdown]
# Check below for variables with missing values (to impute.)

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .isnull()\
  .sum(axis=0)\
  .sort_values(ascending=False)[lambda x: x > 0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>
# IND_INC_AVG         444
# DEP_INC_AVG         433
# IND_INC_N           426
# DEP_INC_N           426
# DEP_STAT_PCT_IND    355
# APPL_SCH_PCT_GE2    249
# APPL_SCH_N           73
# NPCURL               64
# UG25abv              61
# CDR3                 59
# INSTURL              57
# PCTPELL              23
# PCTFLOAN             23
# TUITFTE              21
# INEXPFTE             21
# PPTUG_EF             14
# UGDS_HISP             3
# UGDS                  3
# UGDS_WHITE            3
# UGDS_BLACK            3
# UGDS_ASIAN            3
# UGDS_UNKN             3
# UGDS_NRA              3
# UGDS_AIAN             3
# LOCALE                3
# UGDS_2MOR             3
# UGDS_NHPI             3
# dtype: int64
# </div>

# %% [markdown]
# Check the datatypes of the columns with missing values.

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .pipe(lambda df: df.loc[:,df.isnull().any()])\
  .dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>
# INSTURL              object
# NPCURL               object
# LOCALE              float64
# UGDS                float64
# UGDS_WHITE          float64
# UGDS_BLACK          float64
# UGDS_HISP           float64
# UGDS_ASIAN          float64
# UGDS_AIAN           float64
# UGDS_NHPI           float64
# UGDS_2MOR           float64
# UGDS_NRA            float64
# UGDS_UNKN           float64
# PPTUG_EF            float64
# TUITFTE             float64
# INEXPFTE            float64
# PCTPELL             float64
# PCTFLOAN            float64
# UG25abv             float64
# CDR3                float64
# DEP_STAT_PCT_IND    float64
# APPL_SCH_PCT_GE2    float64
# DEP_INC_AVG         float64
# IND_INC_AVG         float64
# DEP_INC_N           float64
# IND_INC_N           float64
# APPL_SCH_N          float64
# dtype: object
# </div>

# %% [markdown]
# As a first attempt I tried using values as 'median'. This silently didn't work. Notice below.

# %%
NPCURL_ndx = read_college_scorecard()\
               .dropna(thresh=7024,axis=1)\
               .dropna(thresh= 254,axis=0)\
               .loc[:,'NPCURL']\
               .isnull()
NPCURL_ndx
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2827: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code):
# <span class="ansired">Out[</span><span class="ansired">15</span><span class="ansired">]: </span>
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 7353    False
# 7354    False
# 7355    False
# 7356    False
# 7357    False
# 7358    False
# 7359    False
# 7360    False
# 7361    False
# 7362    False
# 7363    False
# 7364    False
# 7365    False
# 7366    False
# 7367    False
# 7368    False
# 7369    False
# 7370    False
# 7371    False
# 7372    False
# 7373    False
# 7374    False
# 7375    False
# 7376    False
# 7377    False
# 7378    False
# 7379    False
# 7380    False
# 7381    False
# 7382    False
# Name: NPCURL, dtype: bool
# </div>

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .fillna(value='median')\
  .loc[NPCURL_ndx,['NPCURL','UGDS']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>
#       NPCURL    UGDS
# 58    median      80
# 73    median       2
# 165   median      76
# 387   median    1101
# 397   median     182
# 461   median     191
# 494   median     506
# 691   median     422
# 895   median      53
# 918   median      60
# 990   median      57
# 1063  median  median
# 1149  median     121
# 1152  median     124
# 1164  median     220
# 1614  median     738
# 1880  median     200
# 1918  median       0
# 1932  median     131
# 2069  median     654
# 2114  median     281
# 2130  median     375
# 2196  median     810
# 2207  median       8
# 2262  median    2766
# 2274  median      41
# 2430  median      79
# 2530  median      15
# 2647  median     346
# 3013  median      99
# ...      ...     ...
# 3436  median     664
# 3449  median      25
# 3517  median     205
# 3564  median      18
# 3698  median     243
# 3778  median     310
# 3840  median      10
# 3866  median     701
# 4246  median      88
# 4270  median     650
# 4338  median      25
# 4340  median     137
# 4375  median      28
# 4583  median     108
# 4758  median      20
# 4769  median      72
# 4972  median     212
# 5010  median     313
# 5244  median       6
# 5265  median      91
# 5431  median      31
# 5646  median       6
# 6181  median      22
# 6358  median     119
# 6404  median      38
# 6511  median     126
# 6585  median      60
# 6760  median     118
# 6836  median     249
# 7278  median     165
#
# [64 rows x 2 columns]
# </div>

# %% [markdown]
# Replacing the `object` variables `NPCURL` and `INSTURL` with the string `NA` seems reasonable, replacing it with the mode does not seem reasonable. The code below does just that.

# %%
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .fillna(value={'NPCURL': 'NA', 
                 'INSTURL': 'NA'})\
  .loc[NPCURL_ndx,['NPCURL','UGDS']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>
#      NPCURL    UGDS
# 58       NA    80.0
# 73       NA     2.0
# 165      NA    76.0
# 387      NA  1101.0
# 397      NA   182.0
# 461      NA   191.0
# 494      NA   506.0
# 691      NA   422.0
# 895      NA    53.0
# 918      NA    60.0
# 990      NA    57.0
# 1063     NA     NaN
# 1149     NA   121.0
# 1152     NA   124.0
# 1164     NA   220.0
# 1614     NA   738.0
# 1880     NA   200.0
# 1918     NA     0.0
# 1932     NA   131.0
# 2069     NA   654.0
# 2114     NA   281.0
# 2130     NA   375.0
# 2196     NA   810.0
# 2207     NA     8.0
# 2262     NA  2766.0
# 2274     NA    41.0
# 2430     NA    79.0
# 2530     NA    15.0
# 2647     NA   346.0
# 3013     NA    99.0
# ...     ...     ...
# 3436     NA   664.0
# 3449     NA    25.0
# 3517     NA   205.0
# 3564     NA    18.0
# 3698     NA   243.0
# 3778     NA   310.0
# 3840     NA    10.0
# 3866     NA   701.0
# 4246     NA    88.0
# 4270     NA   650.0
# 4338     NA    25.0
# 4340     NA   137.0
# 4375     NA    28.0
# 4583     NA   108.0
# 4758     NA    20.0
# 4769     NA    72.0
# 4972     NA   212.0
# 5010     NA   313.0
# 5244     NA     6.0
# 5265     NA    91.0
# 5431     NA    31.0
# 5646     NA     6.0
# 6181     NA    22.0
# 6358     NA   119.0
# 6404     NA    38.0
# 6511     NA   126.0
# 6585     NA    60.0
# 6760     NA   118.0
# 6836     NA   249.0
# 7278     NA   165.0
#
# [64 rows x 2 columns]
# </div>

# %% [markdown]
# The remaining variables are numeric and will be filled by their (respective) medians, but each variable has a different median.
#
# This command creates a dictionary whose keys are variables with missing values and values are the medians (of the key variable.) These medians are calculated by ignoring the missing values.

# %%
median_dict = \
  read_college_scorecard()\
    .dropna(thresh=7024,axis=1)\
    .dropna(thresh= 254,axis=0)\
    .fillna(value={'NPCURL': 'NA', 
                   'INSTURL': 'NA'})\
    .pipe(lambda df: df.loc[:,df.isnull().any()])\
    .apply(lambda x: x.median(skipna=True),axis=0)\
    .to_dict()
(median_dict['UGDS'], 
 median_dict
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">18</span><span class="ansired">]: </span>
# (434.0,
#  {&apos;UGDS_ASIAN&apos;: 0.011900000000000001,
#   &apos;PCTFLOAN&apos;: 0.59260000000000002,
#   &apos;CDR3&apos;: 0.127,
#   &apos;UGDS_NRA&apos;: 0.0,
#   &apos;UGDS_WHITE&apos;: 0.56520000000000004,
#   &apos;PPTUG_EF&apos;: 0.15034999999999998,
#   &apos;DEP_STAT_PCT_IND&apos;: 0.59765625,
#   &apos;DEP_INC_AVG&apos;: 41768.517800000001,
#   &apos;PCTPELL&apos;: 0.51649999999999996,
#   &apos;UGDS_UNKN&apos;: 0.0146,
#   &apos;UG25abv&apos;: 0.41339999999999999,
#   &apos;IND_INC_N&apos;: 452.5,
#   &apos;UGDS&apos;: 434.0,
#   &apos;LOCALE&apos;: 21.0,
#   &apos;DEP_INC_N&apos;: 534.0,
#   &apos;UGDS_NHPI&apos;: 0.0,
#   &apos;UGDS_HISP&apos;: 0.068500000000000005,
#   &apos;TUITFTE&apos;: 8595.0,
#   &apos;INEXPFTE&apos;: 5085.0,
#   &apos;UGDS_2MOR&apos;: 0.0155,
#   &apos;APPL_SCH_PCT_GE2&apos;: 0.41740268200000002,
#   &apos;UGDS_BLACK&apos;: 0.099400000000000002,
#   &apos;IND_INC_AVG&apos;: 18127.085595,
#   &apos;UGDS_AIAN&apos;: 0.0027000000000000001,
#   &apos;APPL_SCH_N&apos;: 981.0})
# </div>

# %% [markdown]
# The `median_dict` dictionary is used as the `value` parameter below.

# %%
median_dict = \
  read_college_scorecard()\
    .dropna(thresh=7024,axis=1)\
    .dropna(thresh= 254,axis=0)\
    .fillna(value={'NPCURL': 'NA', 
                   'INSTURL': 'NA'})\
    .pipe(lambda df: df.loc[:,df.isnull().any()])\
    .apply(lambda x: x.median(skipna=True),axis=0)\
    .to_dict()
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .fillna(value={'NPCURL': 'NA',
                 'INSTURL': 'NA'})\
  .fillna(value=median_dict)\
  .loc[NPCURL_ndx,['NPCURL','UGDS']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">19</span><span class="ansired">]: </span>
#      NPCURL    UGDS
# 58       NA    80.0
# 73       NA     2.0
# 165      NA    76.0
# 387      NA  1101.0
# 397      NA   182.0
# 461      NA   191.0
# 494      NA   506.0
# 691      NA   422.0
# 895      NA    53.0
# 918      NA    60.0
# 990      NA    57.0
# 1063     NA   434.0
# 1149     NA   121.0
# 1152     NA   124.0
# 1164     NA   220.0
# 1614     NA   738.0
# 1880     NA   200.0
# 1918     NA     0.0
# 1932     NA   131.0
# 2069     NA   654.0
# 2114     NA   281.0
# 2130     NA   375.0
# 2196     NA   810.0
# 2207     NA     8.0
# 2262     NA  2766.0
# 2274     NA    41.0
# 2430     NA    79.0
# 2530     NA    15.0
# 2647     NA   346.0
# 3013     NA    99.0
# ...     ...     ...
# 3436     NA   664.0
# 3449     NA    25.0
# 3517     NA   205.0
# 3564     NA    18.0
# 3698     NA   243.0
# 3778     NA   310.0
# 3840     NA    10.0
# 3866     NA   701.0
# 4246     NA    88.0
# 4270     NA   650.0
# 4338     NA    25.0
# 4340     NA   137.0
# 4375     NA    28.0
# 4583     NA   108.0
# 4758     NA    20.0
# 4769     NA    72.0
# 4972     NA   212.0
# 5010     NA   313.0
# 5244     NA     6.0
# 5265     NA    91.0
# 5431     NA    31.0
# 5646     NA     6.0
# 6181     NA    22.0
# 6358     NA   119.0
# 6404     NA    38.0
# 6511     NA   126.0
# 6585     NA    60.0
# 6760     NA   118.0
# 6836     NA   249.0
# 7278     NA   165.0
#
# [64 rows x 2 columns]
# </div>

# %% [markdown]
# Check that there are no remaining missing values.

# %%
median_dict = \
  read_college_scorecard()\
    .dropna(thresh=7024,axis=1)\
    .dropna(thresh= 254,axis=0)\
    .fillna(value={'NPCURL': 'NA', 
                   'INSTURL': 'NA'})\
    .pipe(lambda df: df.loc[:,df.isnull().any()])\
    .apply(lambda x: x.median(skipna=True),axis=0)\
    .to_dict()
read_college_scorecard()\
  .dropna(thresh=7024,axis=1)\
  .dropna(thresh= 254,axis=0)\
  .fillna(value={'NPCURL': 'NA',
                 'INSTURL': 'NA'})\
  .fillna(value=median_dict)\
  .isnull()\
  .sum(axis=0)\
  .sort_values(ascending=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">20</span><span class="ansired">]: </span>
# APPL_SCH_N    0
# CIP11CERT1    0
# CIP09BACHL    0
# CIP10CERT1    0
# CIP10CERT2    0
# CIP10ASSOC    0
# CIP10CERT4    0
# CIP10BACHL    0
# CIP11CERT2    0
# CIP09ASSOC    0
# CIP11ASSOC    0
# CIP11CERT4    0
# CIP11BACHL    0
# CIP12CERT1    0
# CIP12CERT2    0
# CIP12ASSOC    0
# CIP09CERT4    0
# CIP09CERT2    0
# CIP23BACHL    0
# CIP04ASSOC    0
# CIP03CERT2    0
# CIP03ASSOC    0
# CIP03CERT4    0
# CIP03BACHL    0
# CIP04CERT1    0
# CIP04CERT2    0
# CIP04CERT4    0
# CIP09CERT1    0
# CIP04BACHL    0
# CIP05CERT1    0
#              ..
# CIP42CERT2    0
# CIP42ASSOC    0
# CIP42CERT4    0
# CIP42BACHL    0
# CIP43CERT2    0
# CIP38CERT2    0
# CIP43ASSOC    0
# CIP43CERT4    0
# CIP43BACHL    0
# CIP44CERT1    0
# CIP44CERT2    0
# CIP44ASSOC    0
# CIP41CERT4    0
# CIP41ASSOC    0
# CIP41CERT2    0
# CIP41CERT1    0
# CIP40BACHL    0
# CIP40CERT4    0
# CIP40ASSOC    0
# CIP40CERT2    0
# CIP40CERT1    0
# CIP39BACHL    0
# CIP39CERT4    0
# CIP39ASSOC    0
# CIP39CERT2    0
# CIP39CERT1    0
# CIP38BACHL    0
# CIP38CERT4    0
# CIP38ASSOC    0
# ﻿UNITID       0
# dtype: int64
# </div>

# %% [markdown]
# ## Final Code
#
# The code that reads the dataset and deals with missing values is contained in the cell below.

# %%
def read_college_scorecard(file_path='/dbfs/mnt/datalab-datasets/college-scorecard/MERGED2013_PP.csv',
                           n_rows=None):
  return pd.read_csv(file_path,
                     nrows=n_rows,
                     na_values=['PrivacySuppressed']
                     )
def fix_missing_values(df):
  median_dict = \
    read_college_scorecard()\
      .dropna(thresh=7024,axis=1)\
      .dropna(thresh= 254,axis=0)\
      .fillna(value={'NPCURL': 'NA', 
                     'INSTURL': 'NA'})\
      .pipe(lambda df: df.loc[:,df.isnull().any()])\
      .apply(lambda x: x.median(skipna=True),axis=0)\
      .to_dict()
  return df.dropna(thresh=7024,axis=1)\
           .dropna(thresh= 254,axis=0)\
           .fillna(value={'NPCURL': 'NA',
                          'INSTURL': 'NA'})\
           .fillna(value=median_dict)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# These functions are used as:

# %%
read_college_scorecard()\
  .pipe(fix_missing_values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# There's always something. See warning below.

# %%
x = read_college_scorecard().pipe(fix_missing_values)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
x.columns[[7,9]]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">32</span><span class="ansired">]: </span>Index([&apos;INSTURL&apos;, &apos;HCM2&apos;], dtype=&apos;object&apos;)
# </div>

# %%
x.iloc[:,[7,9]].dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">29</span><span class="ansired">]: </span>
# INSTURL    object
# HCM2        int64
# dtype: object
# </div>

# %%
x.iloc[:,[7,9]].head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">33</span><span class="ansired">]: </span>
#                           INSTURL  HCM2
# 0                   www.aamu.edu/     0
# 1                     www.uab.edu     0
# 2       www.amridgeuniversity.edu     0
# 3                     www.uah.edu     0
# 4  www.alasu.edu/email/index.aspx     0
# </div>

# %% [markdown]
# __The End__
