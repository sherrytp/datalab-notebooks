# %%
import pandas as pd
import numpy  as np
pd.__version__

# %%
# %sh ls -l `which python`

# %%
# %sh
echo 'import pandas as pd'  >  /tmp/sdf.py
echo 'print pd.__version__' >> /tmp/sdf.py
/databricks/python2/bin/python /tmp/sdf.py
/usr/bin/python2.7             /tmp/sdf.py
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.18.1
# Traceback (most recent call last):
#   File &quot;/tmp/sdf.py&quot;, line 1, in &lt;module&gt;
#     import pandas as pd
# ImportError: No module named pandas
# </div>
